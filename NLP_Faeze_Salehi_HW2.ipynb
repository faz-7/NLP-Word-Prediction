# %% [markdown]
# # **1. Pre Processing**
#
# ---

# %% [markdown]
# **install Hazm library**

# %%
# !pip install hazm
# Out:
# Requirement already satisfied: hazm in /usr/local/lib/python3.10/dist-packages (0.10.0)
# Requirement already satisfied: fasttext-wheel<0.10.0,>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from hazm) (0.9.2)
# Requirement already satisfied: flashtext<3.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from hazm) (2.7)
# Requirement already satisfied: gensim<5.0.0,>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from hazm) (4.3.2)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from hazm) (3.8.1)
# Requirement already satisfied: numpy==1.24.3 in /usr/local/lib/python3.10/dist-packages (from hazm) (1.24.3)
# Requirement already satisfied: python-crfsuite<0.10.0,>=0.9.9 in /usr/local/lib/python3.10/dist-packages (from hazm) (0.9.10)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.2.2 in /usr/local/lib/python3.10/dist-packages (from hazm) (1.2.2)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.10/dist-packages (from fasttext-wheel<0.10.0,>=0.9.2->hazm) (2.12.0)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext-wheel<0.10.0,>=0.9.2->hazm) (67.7.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim<5.0.0,>=4.3.1->hazm) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim<5.0.0,>=4.3.1->hazm) (6.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->hazm) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->hazm) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->hazm) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->hazm) (4.66.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=1.2.2->hazm) (3.4.0)

# %% [markdown]
# # **Import library**

# %%
import pandas as pd
from hazm import sent_tokenize, word_tokenize, stopwords_list, Normalizer, POSTagger
import re
import string
from collections import Counter
from itertools import chain

import nltk
from nltk.probability import LaplaceProbDist, SimpleGoodTuringProbDist

# %% [markdown]
# # **Read file**

# %%
data = pd.read_csv('/content/digikala_comment.csv')

# %% [markdown]
# # **Tpkenize to sentences**

# %%
sentences = [sent_tokenize(comment) for comment in data['comment']]

sentences[-2]
# Out:
# ['سلام ٬ چندماهی میشه این پاور بانک رو تهیه کردم ٬ طبق تستی که انجام دادم 2 بار گوشی 3200 میلی آمپری رو شارژ میکنه که جمعاً 6400 میلی آمپر اینکه گفتن 12.500 ٬ ادعایی بیش نیست خیلی طول میکشه خودش شارژ شه ٬ زودم خالی میشه عدد 100 رو هم نمیتونه نشون بده چون LED که داره 2 رقمیه ٬ پس انتهاش 99 هست وزنش هم زیاده']

# %% [markdown]
# # **Remove Punctuation**

# %%
sentences = [[re.sub(r'[^\w\s]', '', sentence) for sentence in sublist] for sublist in sentences]

sentences[-2]
# Out:
# ['سلام  چندماهی میشه این پاور بانک رو تهیه کردم  طبق تستی که انجام دادم 2 بار گوشی 3200 میلی آمپری رو شارژ میکنه که جمعا 6400 میلی آمپر اینکه گفتن 12500  ادعایی بیش نیست خیلی طول میکشه خودش شارژ شه  زودم خالی میشه عدد 100 رو هم نمیتونه نشون بده چون LED که داره 2 رقمیه  پس انتهاش 99 هست وزنش هم زیاده']

# %% [markdown]
# # **Rmove Extra Blanck Space**

# %%
sentences = [[re.sub(r"^\s+|\s+$", "", re.sub(r'\s+', ' ', sentence)) for sentence in sublist] for sublist in sentences]

sentences[-2]
# Out:
# ['سلام چندماهی میشه این پاور بانک رو تهیه کردم طبق تستی که انجام دادم 2 بار گوشی 3200 میلی آمپری رو شارژ میکنه که جمعا 6400 میلی آمپر اینکه گفتن 12500 ادعایی بیش نیست خیلی طول میکشه خودش شارژ شه زودم خالی میشه عدد 100 رو هم نمیتونه نشون بده چون LED که داره 2 رقمیه پس انتهاش 99 هست وزنش هم زیاده']

# %% [markdown]
# # **Start and Stop Token**

# %%
SOS = "<s> "
EOS = "</s>"
UNK = "<UNK>"

def add_start_end_tokens(sentences, n):
    """Wrap each sentence in SOS and EOS tokens.

    For n >= 2, n-1 SOS tokens are added, otherwise only one is added.

    Args:
        sentences (list of str): the sentences to wrap.
        n (int): order of the n-gram model which will use these sentences.
    Returns:
        List of sentences with SOS and EOS tokens wrapped around them.

    """
    sos = SOS * (n-1) if n > 1 else SOS
    return [['{}{} {}'.format(sos, sentence, EOS) for sentence in sublist] for sublist in sentences]

# %% [markdown]
# # **Replace Singletones words**

# %%
def replace_singletons(sentences):
    """Replace tokens which appear only once in the corpus with <UNK>.

    Args:
        tokens (list of str): the tokens comprising the corpus.
    Returns:
        The same list of tokens with each singleton replaced by <UNK>.

    """
    # Tokenize each sentence using word_tokenize
    words = [sentence.split() for sentence in chain.from_iterable(sentences)]

    # Flatten the list of lists
    flat_tokens = list(chain.from_iterable(words))

    # Count the frequency of each word
    vocab = Counter(flat_tokens)
    return [token if vocab[token] > 1 else UNK for token in flat_tokens]

# %% [markdown]
# # **2. Model Language**
#
# ---

# %% [markdown]
# # **Generate N-gram**

# %%
def ngram(sentences, grams):
    model = {}
    sentences = add_start_end_tokens(sentences, grams)
    words = replace_singletons(sentences)
    for i in range(len(words) - grams + 1):
        n_gram = tuple(words[i:i + grams])
        if n_gram in model.keys():
            # Increment the count for this n-gram
            model[n_gram] += 1
        else:
            # Initialize this n-gram count to 1
            model[n_gram] = 1

    return model

# %% [markdown]
# # **Ngrams**

# %%
unigrams = ngram(sentences, 1)
bigrams = ngram(sentences, 2)
trigrams = ngram(sentences, 3)

print(f"unigrams:\n{unigrams}\n\nbigrams:\n{bigrams}\n\ntrigrams:\n{trigrams}")
# Out:
# unigrams:
# {('<s>',): 463, ('نسبت',): 26, ('به',): 153, ('قیمتش',): 18, ('ارزش',): 11, ('خرید',): 28, ('داره',): 73, ('<UNK>',): 1483, ('طراحیش',): 2, ('قشنگه',): 3, ('تنها',): 4, ('هست',): 56, ('که',): 187, ('باعث',): 11, ('میشه',): 37, ('باشه',): 28, ('</s>',): 463, ('چند',): 16, ('ماهی',): 2, ('گرفتمش',): 2, ('برای',): 81, ('برنامه',): 8, ('نویسی',): 2, ('و',): 366, ('کارای',): 3, ('گرافیکی',): 2, ('ازش',): 12, ('استفاده',): 39, ('میکنم',): 25, ('واقعا',): 32, ('از',): 208, ('هر',): 18, ('لحاظ',): 4, ('عالیه',): 27, ('جدید',): 2, ('اقا',): 2, ('همه',): 11, ('چیش',): 2, ('خوبه',): 33, ('فقط',): 31, ('پایین',): 11, ('زیاد',): 18, ('با',): 99, ('روشن',): 5, ('شدن',): 6, ('گوشی',): 71, ('بیشتر',): 16, ('هم',): 121, ('نکته',): 2, ('دیگه',): 21, ('اینکه',): 18, ('خاطر',): 4, ('این',): 163, ('یه',): 41, ('گلس',): 6, ('بعد',): 26, ('مدتی',): 2, ('جدا',): 3, ('ولی',): 60, ('در',): 80, ('کل',): 17, ('قیمت',): 33, ('بهترین',): 7, ('دوربین',): 17, ('تا',): 40, ('رم',): 5, ('پی',): 2, ('یو',): 3, ('گرافیک',): 2, ('حسگر',): 2, ('های',): 46, ('مختلف',): 3, ('خیلی',): 111, ('p10',): 2, ('بهتره',): 9, ('تمام',): 3, ('مقایسه',): 4, ('گوشیو',): 2, ('سبک',): 4, ('نمیشه',): 11, ('حتما',): 16, ('پیشنهاد',): 24, ('من',): 97, ('خردکن',): 4, ('رو',): 106, ('گرفتم',): 19, ('کارکرد',): 2, ('خوبی',): 26, ('ظاهر',): 6, ('بقیه',): 5, ('ها',): 34, ('تیغه',): 2, ('بسیار',): 36, ('اگه',): 27, ('موقع',): 4, ('شستن',): 2, ('نباشه',): 3, ('راحت',): 9, ('دستتون',): 2, ('کیفیت',): 49, ('هستش',): 19, ('خوب',): 49, ('خرد',): 3, ('باید',): 22, ('محصول',): 18, ('آسیاب',): 2, ('نیست',): 34, ('نباید',): 3, ('انتظار',): 5, ('کردن',): 9, ('مثل',): 20, ('حد',): 5, ('داشته',): 12, ('ساخت',): 10, ('کشور',): 3, ('بوده',): 3, ('خدا',): 2, ('چینی',): 3, ('خوبیه',): 10, ('مشکلی',): 6, ('بخرین',): 2, ('هدیه',): 6, ('هستم',): 13, ('ظریف',): 4, ('کار',): 16, ('شده',): 17, ('خریدم',): 26, ('راضی',): 23, ('عالی',): 26, ('سلام',): 11, ('کفش',): 2, ('سبکی',): 2, ('جنس',): 15, ('ساخته',): 2, ('نشده',): 2, ('بوی',): 8, ('بدی',): 7, ('میده',): 13, ('نمیدونم',): 6, ('چرا',): 5, ('پشت',): 4, ('پای',): 2, ('منو',): 5, ('اگر',): 14, ('نزدیک',): 2, ('اصلا',): 22, ('نمی',): 9, ('خریدمش',): 2, ('عنوان',): 5, ('بالا',): 11, ('امکانات',): 9, ('یک',): 25, ('ماه',): 8, ('کامل',): 10, ('شارژ',): 20, ('شه',): 7, ('10',): 6, ('ساعت',): 15, ('طول',): 3, ('می',): 24, ('نصف',): 4, ('بشه',): 11, ('شارژش',): 3, ('خیلیا',): 2, ('گفتن',): 5, ('چقدر',): 2, ('خوشگله',): 2, ('وقتی',): 14, ('بهش',): 6, ('میکنی',): 4, ('کنی',): 4, ('برعکس',): 2, ('خراب',): 8, ('نیم',): 3, ('فکر',): 8, ('کنم',): 11, ('البته',): 14, ('زمان',): 4, ('نشه',): 2, ('دم',): 2, ('بر',): 10, ('ایرانی',): 6, ('گرم',): 5, ('ای',): 36, ('مورچه',): 2, ('2',): 7, ('هفته',): 4, ('دارم',): 14, ('کمتر',): 5, ('باسلام',): 2, ('نظر',): 27, ('پوست',): 4, ('چرب',): 2, ('مناسب',): 8, ('است',): 19, ('صورت',): 10, ('خشک',): 5, ('جوش',): 4, ('شد',): 14, ('ویژه',): 5, ('سه',): 10, ('سایز',): 4, ('لازم',): 2, ('چون',): 31, ('بی',): 7, ('بگیرید',): 9, ('قبل',): 10, ('ببینید',): 2, ('تونه',): 2, ('فول',): 4, ('اچ',): 2, ('دی',): 4, ('نشون',): 5, ('بده',): 4, ('نا',): 3, ('امید',): 3, ('شدم',): 9, ('قابلیت',): 4, ('ده',): 5, ('رنگ',): 12, ('قبلی',): 2, ('g3',): 2, ('بود',): 40, ('صفحه',): 13, ('نمایش',): 3, ('اون',): 22, ('کجا',): 2, ('الان',): 8, ('زیبایی',): 5, ('شگفت',): 7, ('انگیز',): 7, ('مشکل',): 8, ('دوربینش',): 2, ('12',): 2, ('کاربردی',): 3, ('میباشد',): 3, ('تاپ',): 2, ('سخت',): 6, ('افزار',): 5, ('قوی',): 3, ('پس',): 13, ('راحتی',): 2, ('بازی',): 4, ('تنظیمات',): 2, ('قابل',): 13, ('حمل',): 2, ('بودن',): 12, ('نداره',): 28, ('باتری',): 14, ('کیبرد',): 2, ('فارسی',): 3, ('همراه',): 6, ('لایت',): 5, ('اشاره',): 2, ('کرد',): 17, ('دو',): 24, ('مورد',): 7, ('متوسط',): 4, ('دوم',): 2, ('قسمت',): 2, ('دلیل',): 5, ('فلزی',): 2, ('میکنه',): 24, ('هارد',): 2, ('لپتاپ',): 2, ('تغییر',): 3, ('کانفیگ',): 4, ('موجود',): 2, ('روی',): 14, ('تجربه',): 4, ('برق',): 3, ('العادس',): 2, ('صداش',): 2, ('یکم',): 8, ('زیاده',): 5, ('ارزه',): 3, ('تو',): 30, ('روزه',): 2, ('تاحالا' ...
#
# bigrams:
# {('<s>', 'نسبت'): 7, ('نسبت', 'به'): 22, ('به', 'قیمتش'): 11, ('قیمتش', 'ارزش'): 1, ('ارزش', 'خرید'): 5, ('خرید', 'داره'): 2, ('داره', '<UNK>'): 6, ('<UNK>', 'طراحیش'): 1, ('طراحیش', 'قشنگه'): 1, ('قشنگه', 'تنها'): 1, ('تنها', '<UNK>'): 1, ('<UNK>', '<UNK>'): 270, ('<UNK>', 'هست'): 12, ('هست', 'که'): 9, ('که', 'باعث'): 4, ('باعث', 'میشه'): 4, ('میشه', '<UNK>'): 7, ('<UNK>', 'باشه'): 9, ('باشه', '</s>'): 13, ('</s>', '<s>'): 462, ('<s>', 'چند'): 7, ('چند', 'ماهی'): 1, ('ماهی', 'میشه'): 1, ('میشه', 'که'): 2, ('که', 'گرفتمش'): 1, ('گرفتمش', '</s>'): 1, ('<s>', 'برای'): 20, ('برای', 'برنامه'): 1, ('برنامه', 'نویسی'): 2, ('نویسی', 'و'): 1, ('و', 'کارای'): 1, ('کارای', 'گرافیکی'): 1, ('گرافیکی', 'ازش'): 1, ('ازش', 'استفاده'): 5, ('استفاده', 'میکنم'): 3, ('میکنم', '</s>'): 8, ('<s>', 'واقعا'): 9, ('واقعا', 'از'): 2, ('از', 'هر'): 3, ('هر', 'لحاظ'): 1, ('لحاظ', '<UNK>'): 1, ('<UNK>', 'عالیه'): 5, ('عالیه', '</s>'): 10, ('<s>', '<UNK>'): 42, ('<UNK>', 'جدید'): 2, ('جدید', '</s>'): 1, ('<s>', 'اقا'): 1, ('اقا', 'همه'): 1, ('همه', 'چیش'): 1, ('چیش', 'خوبه'): 1, ('خوبه', 'فقط'): 2, ('فقط', 'از'): 1, ('از', 'پایین'): 1, ('پایین', 'زیاد'): 1, ('زیاد', '<UNK>'): 4, ('<UNK>', 'داره'): 17, ('داره', 'که'): 4, ('که', 'با'): 5, ('با', 'روشن'): 1, ('روشن', 'شدن'): 1, ('شدن', 'گوشی'): 1, ('گوشی', 'بیشتر'): 1, ('بیشتر', 'هم'): 1, ('هم', 'میشه'): 1, ('میشه', '</s>'): 8, ('<s>', 'و'): 8, ('و', 'نکته'): 1, ('نکته', 'دیگه'): 1, ('دیگه', 'اینکه'): 1, ('اینکه', 'به'): 1, ('به', 'خاطر'): 3, ('خاطر', 'این'): 1, ('این', 'که'): 1, ('که', '<UNK>'): 36, ('<UNK>', 'یه'): 8, ('یه', '<UNK>'): 15, ('هست', 'گلس'): 1, ('گلس', 'بعد'): 1, ('بعد', 'یه'): 1, ('یه', 'مدتی'): 1, ('مدتی', 'جدا'): 1, ('جدا', '<UNK>'): 1, ('<UNK>', '</s>'): 80, ('<s>', 'ولی'): 5, ('ولی', 'در'): 2, ('در', 'کل'): 16, ('کل', 'با'): 2, ('با', 'این'): 10, ('این', 'قیمت'): 6, ('قیمت', 'بهترین'): 1, ('بهترین', 'گوشی'): 2, ('گوشی', 'هست'): 1, ('هست', 'و'): 11, ('و', 'همه'): 1, ('همه', '<UNK>'): 2, ('داره', 'از'): 1, ('از', 'دوربین'): 2, ('دوربین', '<UNK>'): 5, ('<UNK>', 'تا'): 6, ('تا', 'رم'): 1, ('رم', 'و'): 1, ('و', '<UNK>'): 80, ('<UNK>', 'پی'): 1, ('پی', 'یو'): 1, ('یو', 'و'): 1, ('و', 'گرافیک'): 1, ('گرافیک', 'و'): 1, ('و', 'حسگر'): 1, ('حسگر', 'های'): 2, ('های', 'مختلف'): 2, ('مختلف', 'و'): 1, ('و', 'خیلی'): 6, ('خیلی', '<UNK>'): 19, ('<UNK>', 'دیگه'): 4, ('دیگه', '</s>'): 1, ('<UNK>', 'p10'): 1, ('p10', '<UNK>'): 2, ('<UNK>', 'و'): 71, ('و', 'دوربین'): 1, ('دوربین', 'و'): 2, ('<UNK>', 'از'): 29, ('از', 'این'): 18, ('این', 'خیلی'): 1, ('خیلی', 'بهتره'): 5, ('بهتره', '<UNK>'): 2, ('<UNK>', 'تمام'): 1, ('تمام', 'مقایسه'): 1, ('مقایسه', 'های'): 1, ('های', 'p10'): 1, ('<UNK>', 'این'): 15, ('این', 'گوشیو'): 2, ('گوشیو', '<UNK>'): 2, ('<UNK>', 'سبک'): 2, ('سبک', 'و'): 2, ('<UNK>', 'خیلی'): 16, ('خیلی', 'خوبه'): 12, ('خوبه', '<UNK>'): 2, ('<UNK>', 'نمیشه'): 2, ('نمیشه', '</s>'): 3, ('<s>', 'خیلی'): 18, ('خوبه', '</s>'): 11, ('<s>', 'حتما'): 8, ('حتما', 'پیشنهاد'): 8, ('پیشنهاد', 'میکنم'): 14, ('<s>', 'من'): 34, ('من', 'چند'): 3, ('چند', '<UNK>'): 3, ('این', 'خردکن'): 1, ('خردکن', 'رو'): 1, ('رو', 'گرفتم'): 4, ('گرفتم', '</s>'): 4, ('واقعا', 'کارکرد'): 1, ('کارکرد', 'خوبی'): 1, ('خوبی', '<UNK>'): 6, ('<UNK>', 'ظاهر'): 3, ('ظاهر', 'خردکن'): 1, ('خردکن', 'هم'): 1, ('هم', 'به'): 4, ('به', 'نسبت'): 3, ('نسبت', 'بقیه'): 2, ('بقیه', 'خردکن'): 1, ('خردکن', 'ها'): 1, ('ها', 'خیلی'): 1, ('<s>', 'تیغه'): 1, ('تیغه', 'های'): 1, ('های', 'بسیار'): 1, ('بسیار', '<UNK>'): 7, ('که', 'اگه'): 3, ('اگه', 'موقع'): 1, ('موقع', 'شستن'): 1, ('شستن', '<UNK>'): 1, ('<UNK>', 'نباشه'): 1, ('نباشه', 'خیلی'): 1, ('خیلی', 'راحت'): 3, ('راحت', 'دستتون'): 1, ('دستتون', 'رو'): 1, ('رو', '<UNK>'): 20, ('و', 'تیغه'): 1, ('تیغه', 'هم'): 1, ('هم', 'که'): 1, ('که', 'خیلی'): 6, ('خیلی', 'با'): 5, ('با', 'کیفیت'): 12, ('کیفیت', 'هستش'): 1, ('هستش', '</s>'): 6, ('و', '</s>'): 1, ('<s>', 'رو'): 1, ('رو', 'خوب'): 4, ('خوب', 'خرد'): 1, ('خرد', '<UNK>'): 1, ('<UNK>', 'باید'): 3, ('باید', '<UNK>'): 8, ('باشه', 'این'): 1, ('این', 'محصول'): 8, ('محص ...
#
# trigrams:
# {('<s>', '<s>', 'نسبت'): 7, ('<s>', 'نسبت', 'به'): 7, ('نسبت', 'به', 'قیمتش'): 9, ('به', 'قیمتش', 'ارزش'): 1, ('قیمتش', 'ارزش', 'خرید'): 1, ('ارزش', 'خرید', 'داره'): 2, ('خرید', 'داره', '<UNK>'): 1, ('داره', '<UNK>', 'طراحیش'): 1, ('<UNK>', 'طراحیش', 'قشنگه'): 1, ('طراحیش', 'قشنگه', 'تنها'): 1, ('قشنگه', 'تنها', '<UNK>'): 1, ('تنها', '<UNK>', '<UNK>'): 1, ('<UNK>', '<UNK>', '<UNK>'): 56, ('<UNK>', '<UNK>', 'هست'): 5, ('<UNK>', 'هست', 'که'): 1, ('هست', 'که', 'باعث'): 1, ('که', 'باعث', 'میشه'): 2, ('باعث', 'میشه', '<UNK>'): 2, ('میشه', '<UNK>', '<UNK>'): 2, ('<UNK>', '<UNK>', 'باشه'): 4, ('<UNK>', 'باشه', '</s>'): 3, ('باشه', '</s>', '<s>'): 13, ('</s>', '<s>', '<s>'): 462, ('<s>', '<s>', 'چند'): 7, ('<s>', 'چند', 'ماهی'): 1, ('چند', 'ماهی', 'میشه'): 1, ('ماهی', 'میشه', 'که'): 1, ('میشه', 'که', 'گرفتمش'): 1, ('که', 'گرفتمش', '</s>'): 1, ('گرفتمش', '</s>', '<s>'): 1, ('<s>', '<s>', 'برای'): 20, ('<s>', 'برای', 'برنامه'): 1, ('برای', 'برنامه', 'نویسی'): 1, ('برنامه', 'نویسی', 'و'): 1, ('نویسی', 'و', 'کارای'): 1, ('و', 'کارای', 'گرافیکی'): 1, ('کارای', 'گرافیکی', 'ازش'): 1, ('گرافیکی', 'ازش', 'استفاده'): 1, ('ازش', 'استفاده', 'میکنم'): 1, ('استفاده', 'میکنم', '</s>'): 2, ('میکنم', '</s>', '<s>'): 8, ('<s>', '<s>', 'واقعا'): 9, ('<s>', 'واقعا', 'از'): 1, ('واقعا', 'از', 'هر'): 1, ('از', 'هر', 'لحاظ'): 1, ('هر', 'لحاظ', '<UNK>'): 1, ('لحاظ', '<UNK>', 'عالیه'): 1, ('<UNK>', 'عالیه', '</s>'): 2, ('عالیه', '</s>', '<s>'): 10, ('<s>', '<s>', '<UNK>'): 42, ('<s>', '<UNK>', '<UNK>'): 6, ('<UNK>', '<UNK>', 'جدید'): 1, ('<UNK>', 'جدید', '</s>'): 1, ('جدید', '</s>', '<s>'): 1, ('<s>', '<s>', 'اقا'): 1, ('<s>', 'اقا', 'همه'): 1, ('اقا', 'همه', 'چیش'): 1, ('همه', 'چیش', 'خوبه'): 1, ('چیش', 'خوبه', 'فقط'): 1, ('خوبه', 'فقط', 'از'): 1, ('فقط', 'از', 'پایین'): 1, ('از', 'پایین', 'زیاد'): 1, ('پایین', 'زیاد', '<UNK>'): 1, ('زیاد', '<UNK>', 'داره'): 1, ('<UNK>', 'داره', 'که'): 3, ('داره', 'که', 'با'): 1, ('که', 'با', 'روشن'): 1, ('با', 'روشن', 'شدن'): 1, ('روشن', 'شدن', 'گوشی'): 1, ('شدن', 'گوشی', 'بیشتر'): 1, ('گوشی', 'بیشتر', 'هم'): 1, ('بیشتر', 'هم', 'میشه'): 1, ('هم', 'میشه', '</s>'): 1, ('میشه', '</s>', '<s>'): 8, ('<s>', '<s>', 'و'): 8, ('<s>', 'و', 'نکته'): 1, ('و', 'نکته', 'دیگه'): 1, ('نکته', 'دیگه', 'اینکه'): 1, ('دیگه', 'اینکه', 'به'): 1, ('اینکه', 'به', 'خاطر'): 1, ('به', 'خاطر', 'این'): 1, ('خاطر', 'این', 'که'): 1, ('این', 'که', '<UNK>'): 1, ('که', '<UNK>', 'یه'): 1, ('<UNK>', 'یه', '<UNK>'): 4, ('یه', '<UNK>', '<UNK>'): 6, ('<UNK>', 'هست', 'گلس'): 1, ('هست', 'گلس', 'بعد'): 1, ('گلس', 'بعد', 'یه'): 1, ('بعد', 'یه', 'مدتی'): 1, ('یه', 'مدتی', 'جدا'): 1, ('مدتی', 'جدا', '<UNK>'): 1, ('جدا', '<UNK>', '</s>'): 1, ('<UNK>', '</s>', '<s>'): 80, ('<s>', '<s>', 'ولی'): 5, ('<s>', 'ولی', 'در'): 1, ('ولی', 'در', 'کل'): 1, ('در', 'کل', 'با'): 2, ('کل', 'با', 'این'): 1, ('با', 'این', 'قیمت'): 4, ('این', 'قیمت', 'بهترین'): 1, ('قیمت', 'بهترین', 'گوشی'): 1, ('بهترین', 'گوشی', 'هست'): 1, ('گوشی', 'هست', 'و'): 1, ('هست', 'و', 'همه'): 1, ('و', 'همه', '<UNK>'): 1, ('همه', '<UNK>', 'داره'): 1, ('<UNK>', 'داره', 'از'): 1, ('داره', 'از', 'دوربین'): 1, ('از', 'دوربین', '<UNK>'): 2, ('دوربین', '<UNK>', 'تا'): 1, ('<UNK>', 'تا', 'رم'): 1, ('تا', 'رم', 'و'): 1, ('رم', 'و', '<UNK>'): 1, ('و', '<UNK>', 'پی'): 1, ('<UNK>', 'پی', 'یو'): 1, ('پی', 'یو', 'و'): 1, ('یو', 'و', 'گرافیک'): 1, ('و', 'گرافیک', 'و'): 1, ('گرافیک', 'و', 'حسگر'): 1, ('و', 'حسگر', 'های'): 1, ('حسگر', 'های', 'مختلف'): 1, ('های', 'مختلف', 'و'): 1, ('مختلف', 'و', 'خیلی'): 1, ('و', 'خیلی', '<UNK>'): 3, ('خیلی', '<UNK>', 'دیگه'): 1, ('<UNK>', 'دیگه', '</s>'): 1, ('دیگه', '</s>', '<s>'): 1, ('<UNK>', '<UNK>', 'p10'): 1, ('<UNK>', 'p10', '<UNK>'): 1, ('p10', '<UNK>', '<UNK>'): 1, ('<UNK>', '<UNK>', 'و'): 19, ('<UNK>', 'و', 'دوربین'): 1, ('و', 'دوربین', 'و'): 1, ('دوربین', 'و', '<UNK>'): 1, ('و', '<UNK>', 'از'): 5, ('<UNK>', 'از', 'این'): 1, ('از', 'این', 'خیلی'): 1, ('این', 'خیلی', 'بهتره'): 1, ('خیلی', 'بهتره', '<UNK>'): 1, ('بهتره', '<UNK>', '<UNK>'): 1, ('<UNK>', '<UNK>', 'تمام'): 1, ('<UNK>', 'تم ...

# %% [markdown]
# # **Sort count matrix**

# %%
sorted_unigrams = sorted(unigrams.items(), key=lambda x: x[1], reverse=True)
sorted_bigrams = sorted(bigrams.items(), key=lambda x: x[1], reverse=True)
sorted_trigrams = sorted(trigrams.items(), key=lambda x: x[1], reverse=True)

# %% [markdown]
# **Top 8 Unigram**

# %%
pd.DataFrame(sorted_unigrams[:8], columns=['unigram', 'count'])
# Out:
#     unigram  count
# 0  (<UNK>,)   1483
# 1    (<s>,)    463
# 2   (</s>,)    463
# 3      (و,)    366
# 4     (از,)    208
# 5     (که,)    187
# 6    (این,)    163
# 7     (به,)    153

# %% [markdown]
# **Top 8 Bigram**

# %%
pd.DataFrame(sorted_bigrams[:8], columns=['bigram', 'count'])
# Out:
#            bigram  count
# 0     (</s>, <s>)    462
# 1  (<UNK>, <UNK>)    270
# 2   (<UNK>, </s>)     80
# 3      (و, <UNK>)     80
# 4      (<UNK>, و)     71
# 5     (<UNK>, که)     48
# 6    (<s>, <UNK>)     42
# 7     (از, <UNK>)     41

# %% [markdown]
# **Top 8 Trigram**

# %%
pd.DataFrame(sorted_trigrams[:8], columns=['trigram', 'count'])
# Out:
#                  trigram  count
# 0       (</s>, <s>, <s>)    462
# 1     (<UNK>, </s>, <s>)     80
# 2  (<UNK>, <UNK>, <UNK>)     56
# 3      (<s>, <s>, <UNK>)     42
# 4         (<s>, <s>, من)     34
# 5      (<UNK>, و, <UNK>)     23
# 6       (<s>, <s>, برای)     20
# 7      (و, <UNK>, <UNK>)     20

# %% [markdown]
# # **Ngrams Probability**

# %%
def estimate_probability(word, previous_n_gram, n_gram_counts):
    previous_n_gram = tuple(previous_n_gram)
    previous_n_gram_count = n_gram_counts.get(previous_n_gram, 0)

    if len(previous_n_gram) == 1:
        # Unigram probability with Laplace smoothing
        prob_dist = nltk.LaplaceProbDist(nltk.FreqDist(n_gram_counts))
        ngram_prob = prob_dist.prob((word,))
    else:
        # Other gram-n probability with SimpleGoodTuring smoothing
        prob_dist = nltk.SimpleGoodTuringProbDist(nltk.FreqDist(n_gram_counts))
        ngram_prob = prob_dist.prob(previous_n_gram + (word,))

    return ngram_prob

# %%
def calculate_ngram_probabilities(ngram_counts):
    ngram_probabilities = {}

    # Iterate over each n-gram and its count
    for ngram, count in ngram_counts.items():
        # Check if it's a unigram or higher order n-gram
        if len(ngram) == 1:
            probability = estimate_probability(ngram[0], (), ngram_counts)
        else:
            probability = estimate_probability(ngram[-1], ngram[:-1], ngram_counts)

        # Store the probability in the dictionary
        ngram_probabilities[ngram] = probability

    return ngram_probabilities

# %%
unigram_prob = calculate_ngram_probabilities(unigrams)
bigram_prob = calculate_ngram_probabilities(bigrams)
trigram_prob = calculate_ngram_probabilities(trigrams)

print(f"unigrams:\n{unigram_prob}\n\nbigrams:\n{bigram_prob}\n\ntrigrams:\n{trigram_prob}")
# Out:
# unigrams:
# {('<s>',): 0.05083912935376905, ('نسبت',): 0.002747043002222248, ('به',): 0.01672093416075611, ('قیمتش',): 0.0018684887298897875, ('ارزش',): 0.001101858726927239, ('خرید',): 0.002966847715077433, ('داره',): 0.007916969937549234, ('<UNK>',): 0.16310058358154794, ('طراحیش',): 0.00014193201410480537, ('قشنگه',): 0.00024184282359126686, ('تنها',): 0.00034578567149146143, ('هست',): 0.00604644204387057, ('که',): 0.020462843164672923, ('باعث',): 0.001101858726927239, ('میشه',): 0.003956380439750571, ('باشه',): 0.002966847715077433, ('</s>',): 0.05083912935376905, ('چند',): 0.0016491333870212207, ('ماهی',): 0.00014193201410480537, ('گرفتمش',): 0.00014193201410480537, ('برای',): 0.008797289984526703, ('برنامه',): 0.0007751033424238826, ('نویسی',): 0.00014193201410480537, ('و',): 0.04016333834191288, ('کارای',): 0.00024184282359126686, ('گرافیکی',): 0.00014193201410480537, ('ازش',): 0.0012111277677633928, ('استفاده',): 0.004176338349341506, ('میکنم',): 0.0026371588651964767, ('واقعا',): 0.003406572004864784, ('از',): 0.022774045916788353, ('هر',): 0.0018684887298897875, ('لحاظ',): 0.00034578567149146143, ('عالیه',): 0.002856939718870172, ('جدید',): 0.00014193201410480537, ('اقا',): 0.00014193201410480537, ('همه',): 0.001101858726927239, ('چیش',): 0.00014193201410480537, ('خوبه',): 0.0035165220846693477, ('فقط',): 0.0032966288158581174, ('پایین',): 0.001101858726927239, ('زیاد',): 0.0018684887298897875, ('با',): 0.010778105645584972, ('روشن',): 0.00045175667174188964, ('شدن',): 0.0005588908289743473, ('گوشی',): 0.007696895596806718, ('بیشتر',): 0.0016491333870212207, ('هم',): 0.013199211564981127, ('نکته',): 0.00014193201410480537, ('دیگه',): 0.0021977823768666786, ('اینکه',): 0.0018684887298897875, ('خاطر',): 0.00034578567149146143, ('این',): 0.017821489366970533, ('یه',): 0.004396311767565098, ('گلس',): 0.0005588908289743473, ('بعد',): 0.002747043002222248, ('مدتی',): 0.00014193201410480537, ('جدا',): 0.00024184282359126686, ('ولی',): 0.006486541223052266, ('در',): 0.008687248214267175, ('کل',): 0.0017587898279324257, ('قیمت',): 0.0035165220846693477, ('بهترین',): 0.0006667537390655324, ('دوربین',): 0.0017587898279324257, ('تا',): 0.004286323261624152, ('رم',): 0.00045175667174188964, ('پی',): 0.00014193201410480537, ('یو',): 0.00024184282359126686, ('گرافیک',): 0.00014193201410480537, ('حسگر',): 0.00014193201410480537, ('های',): 0.004946300178557535, ('مختلف',): 0.00024184282359126686, ('خیلی',): 0.0120986979910242, ('p10',): 0.00014193201410480537, ('بهتره',): 0.000883794086327271, ('تمام',): 0.00024184282359126686, ('مقایسه',): 0.00034578567149146143, ('گوشیو',): 0.00014193201410480537, ('سبک',): 0.00034578567149146143, ('نمیشه',): 0.001101858726927239, ('حتما',): 0.0016491333870212207, ('پیشنهاد',): 0.002527288815626396, ('من',): 0.010558010082515439, ('خردکن',): 0.00034578567149146143, ('رو',): 0.011548447561241622, ('گرفتم',): 0.0019782237329733212, ('کارکرد',): 0.00014193201410480537, ('خوبی',): 0.002747043002222248, ('ظاهر',): 0.0005588908289743473, ('بقیه',): 0.00045175667174188964, ('ها',): 0.0036264784651091333, ('تیغه',): 0.00014193201410480537, ('بسیار',): 0.0038464080860049522, ('اگه',): 0.002856939718870172, ('موقع',): 0.00034578567149146143, ('شستن',): 0.00014193201410480537, ('نباشه',): 0.00024184282359126686, ('راحت',): 0.000883794086327271, ('دستتون',): 0.00014193201410480537, ('کیفیت',): 0.005276323326985212, ('هستش',): 0.0019782237329733212, ('خوب',): 0.005276323326985212, ('خرد',): 0.00024184282359126686, ('باید',): 0.0023075983197032917, ('محصول',): 0.0018684887298897875, ('آسیاب',): 0.00014193201410480537, ('نیست',): 0.0036264784651091333, ('نباید',): 0.00024184282359126686, ('انتظار',): 0.00045175667174188964, ('کردن',): 0.000883794086327271, ('مثل',): 0.0020879896869814263, ('حد',): 0.00045175667174188964, ('داشته',): 0.0012111277677633928, ('ساخت',): 0.0009927331922955417, ('کشور',): 0.00024184282359126686, ('بوده',): 0.00024184282359126686, ('خدا',): 0.00014193201410480537, ('چینی',): 0.00024184282359126686, ...
#
# bigrams:
# {('<s>', 'نسبت'): 6.334726973267453e-05, ('نسبت', 'به'): 6.334726973267453e-05, ('به', 'قیمتش'): 6.334726973267453e-05, ('قیمتش', 'ارزش'): 6.334726973267453e-05, ('ارزش', 'خرید'): 6.334726973267453e-05, ('خرید', 'داره'): 6.334726973267453e-05, ('داره', '<UNK>'): 6.334726973267453e-05, ('<UNK>', 'طراحیش'): 6.334726973267453e-05, ('طراحیش', 'قشنگه'): 6.334726973267453e-05, ('قشنگه', 'تنها'): 6.334726973267453e-05, ('تنها', '<UNK>'): 6.334726973267453e-05, ('<UNK>', '<UNK>'): 6.334726973267453e-05, ('<UNK>', 'هست'): 6.334726973267453e-05, ('هست', 'که'): 6.334726973267453e-05, ('که', 'باعث'): 6.334726973267453e-05, ('باعث', 'میشه'): 6.334726973267453e-05, ('میشه', '<UNK>'): 6.334726973267453e-05, ('<UNK>', 'باشه'): 6.334726973267453e-05, ('باشه', '</s>'): 6.334726973267453e-05, ('</s>', '<s>'): 6.334726973267453e-05, ('<s>', 'چند'): 6.334726973267453e-05, ('چند', 'ماهی'): 6.334726973267453e-05, ('ماهی', 'میشه'): 6.334726973267453e-05, ('میشه', 'که'): 6.334726973267453e-05, ('که', 'گرفتمش'): 6.334726973267453e-05, ('گرفتمش', '</s>'): 6.334726973267453e-05, ('<s>', 'برای'): 6.334726973267453e-05, ('برای', 'برنامه'): 6.334726973267453e-05, ('برنامه', 'نویسی'): 6.334726973267453e-05, ('نویسی', 'و'): 6.334726973267453e-05, ('و', 'کارای'): 6.334726973267453e-05, ('کارای', 'گرافیکی'): 6.334726973267453e-05, ('گرافیکی', 'ازش'): 6.334726973267453e-05, ('ازش', 'استفاده'): 6.334726973267453e-05, ('استفاده', 'میکنم'): 6.334726973267453e-05, ('میکنم', '</s>'): 6.334726973267453e-05, ('<s>', 'واقعا'): 6.334726973267453e-05, ('واقعا', 'از'): 6.334726973267453e-05, ('از', 'هر'): 6.334726973267453e-05, ('هر', 'لحاظ'): 6.334726973267453e-05, ('لحاظ', '<UNK>'): 6.334726973267453e-05, ('<UNK>', 'عالیه'): 6.334726973267453e-05, ('عالیه', '</s>'): 6.334726973267453e-05, ('<s>', '<UNK>'): 6.334726973267453e-05, ('<UNK>', 'جدید'): 6.334726973267453e-05, ('جدید', '</s>'): 6.334726973267453e-05, ('<s>', 'اقا'): 6.334726973267453e-05, ('اقا', 'همه'): 6.334726973267453e-05, ('همه', 'چیش'): 6.334726973267453e-05, ('چیش', 'خوبه'): 6.334726973267453e-05, ('خوبه', 'فقط'): 6.334726973267453e-05, ('فقط', 'از'): 6.334726973267453e-05, ('از', 'پایین'): 6.334726973267453e-05, ('پایین', 'زیاد'): 6.334726973267453e-05, ('زیاد', '<UNK>'): 6.334726973267453e-05, ('<UNK>', 'داره'): 6.334726973267453e-05, ('داره', 'که'): 6.334726973267453e-05, ('که', 'با'): 6.334726973267453e-05, ('با', 'روشن'): 6.334726973267453e-05, ('روشن', 'شدن'): 6.334726973267453e-05, ('شدن', 'گوشی'): 6.334726973267453e-05, ('گوشی', 'بیشتر'): 6.334726973267453e-05, ('بیشتر', 'هم'): 6.334726973267453e-05, ('هم', 'میشه'): 6.334726973267453e-05, ('میشه', '</s>'): 6.334726973267453e-05, ('<s>', 'و'): 6.334726973267453e-05, ('و', 'نکته'): 6.334726973267453e-05, ('نکته', 'دیگه'): 6.334726973267453e-05, ('دیگه', 'اینکه'): 6.334726973267453e-05, ('اینکه', 'به'): 6.334726973267453e-05, ('به', 'خاطر'): 6.334726973267453e-05, ('خاطر', 'این'): 6.334726973267453e-05, ('این', 'که'): 6.334726973267453e-05, ('که', '<UNK>'): 6.334726973267453e-05, ('<UNK>', 'یه'): 6.334726973267453e-05, ('یه', '<UNK>'): 6.334726973267453e-05, ('هست', 'گلس'): 6.334726973267453e-05, ('گلس', 'بعد'): 6.334726973267453e-05, ('بعد', 'یه'): 6.334726973267453e-05, ('یه', 'مدتی'): 6.334726973267453e-05, ('مدتی', 'جدا'): 6.334726973267453e-05, ('جدا', '<UNK>'): 6.334726973267453e-05, ('<UNK>', '</s>'): 6.334726973267453e-05, ('<s>', 'ولی'): 6.334726973267453e-05, ('ولی', 'در'): 6.334726973267453e-05, ('در', 'کل'): 6.334726973267453e-05, ('کل', 'با'): 6.334726973267453e-05, ('با', 'این'): 6.334726973267453e-05, ('این', 'قیمت'): 6.334726973267453e-05, ('قیمت', 'بهترین'): 6.334726973267453e-05, ('بهترین', 'گوشی'): 6.334726973267453e-05, ('گوشی', 'هست'): 6.334726973267453e-05, ('هست', 'و'): 6.334726973267453e-05, ('و', 'همه'): 6.334726973267453e-05, ('همه', '<UNK>'): 6.334726973267453e-05, ('داره', 'از'): 6.334726973267453e-05, ('از', 'دوربین'): 6.334726973267453e-05, ('دوربین', '<UNK>'): 6.334726973267453e-05, ('<UNK>', 'تا'): 6.334726973267453e- ...
#
# trigrams:
# {('<s>', '<s>', 'نسبت'): 0.0005484228847770111, ('<s>', 'نسبت', 'به'): 0.0005484228847770111, ('نسبت', 'به', 'قیمتش'): 0.0007361722873715856, ('به', 'قیمتش', 'ارزش'): 8.373745312063257e-06, ('قیمتش', 'ارزش', 'خرید'): 8.373745312063257e-06, ('ارزش', 'خرید', 'داره'): 6.545120797002752e-05, ('خرید', 'داره', '<UNK>'): 8.373745312063257e-06, ('داره', '<UNK>', 'طراحیش'): 8.373745312063257e-06, ('<UNK>', 'طراحیش', 'قشنگه'): 8.373745312063257e-06, ('طراحیش', 'قشنگه', 'تنها'): 8.373745312063257e-06, ('قشنگه', 'تنها', '<UNK>'): 8.373745312063257e-06, ('تنها', '<UNK>', '<UNK>'): 8.373745312063257e-06, ('<UNK>', '<UNK>', '<UNK>'): 0.005238118251690502, ('<UNK>', '<UNK>', 'هست'): 0.0003635521180790335, ('<UNK>', 'هست', 'که'): 8.373745312063257e-06, ('هست', 'که', 'باعث'): 8.373745312063257e-06, ('که', 'باعث', 'میشه'): 6.545120797002752e-05, ('باعث', 'میشه', '<UNK>'): 6.545120797002752e-05, ('میشه', '<UNK>', '<UNK>'): 6.545120797002752e-05, ('<UNK>', '<UNK>', 'باشه'): 0.0002732314121077292, ('<UNK>', 'باشه', '</s>'): 0.00018565485920881726, ('باشه', '</s>', '<s>'): 0.0011154432717008086, ('</s>', '<s>', '<s>'): 0.04425412842152086, ('<s>', '<s>', 'چند'): 0.0005484228847770111, ('<s>', 'چند', 'ماهی'): 8.373745312063257e-06, ('چند', 'ماهی', 'میشه'): 8.373745312063257e-06, ('ماهی', 'میشه', 'که'): 8.373745312063257e-06, ('میشه', 'که', 'گرفتمش'): 8.373745312063257e-06, ('که', 'گرفتمش', '</s>'): 8.373745312063257e-06, ('گرفتمش', '</s>', '<s>'): 8.373745312063257e-06, ('<s>', '<s>', 'برای'): 0.0017838474255005977, ('<s>', 'برای', 'برنامه'): 8.373745312063257e-06, ('برای', 'برنامه', 'نویسی'): 8.373745312063257e-06, ('برنامه', 'نویسی', 'و'): 8.373745312063257e-06, ('نویسی', 'و', 'کارای'): 8.373745312063257e-06, ('و', 'کارای', 'گرافیکی'): 8.373745312063257e-06, ('کارای', 'گرافیکی', 'ازش'): 8.373745312063257e-06, ('گرافیکی', 'ازش', 'استفاده'): 8.373745312063257e-06, ('ازش', 'استفاده', 'میکنم'): 8.373745312063257e-06, ('استفاده', 'میکنم', '</s>'): 6.545120797002752e-05, ('میکنم', '</s>', '<s>'): 0.0006420549983176896, ('<s>', '<s>', 'واقعا'): 0.0007361722873715856, ('<s>', 'واقعا', 'از'): 8.373745312063257e-06, ('واقعا', 'از', 'هر'): 8.373745312063257e-06, ('از', 'هر', 'لحاظ'): 8.373745312063257e-06, ('هر', 'لحاظ', '<UNK>'): 8.373745312063257e-06, ('لحاظ', '<UNK>', 'عالیه'): 8.373745312063257e-06, ('<UNK>', 'عالیه', '</s>'): 6.545120797002752e-05, ('عالیه', '</s>', '<s>'): 0.0008306448182726552, ('<s>', '<s>', '<UNK>'): 0.0038936950984963343, ('<s>', '<UNK>', '<UNK>'): 0.00045547794409951534, ('<UNK>', '<UNK>', 'جدید'): 8.373745312063257e-06, ('<UNK>', 'جدید', '</s>'): 8.373745312063257e-06, ('جدید', '</s>', '<s>'): 8.373745312063257e-06, ('<s>', '<s>', 'اقا'): 8.373745312063257e-06, ('<s>', 'اقا', 'همه'): 8.373745312063257e-06, ('اقا', 'همه', 'چیش'): 8.373745312063257e-06, ('همه', 'چیش', 'خوبه'): 8.373745312063257e-06, ('چیش', 'خوبه', 'فقط'): 8.373745312063257e-06, ('خوبه', 'فقط', 'از'): 8.373745312063257e-06, ('فقط', 'از', 'پایین'): 8.373745312063257e-06, ('از', 'پایین', 'زیاد'): 8.373745312063257e-06, ('پایین', 'زیاد', '<UNK>'): 8.373745312063257e-06, ('زیاد', '<UNK>', 'داره'): 8.373745312063257e-06, ('<UNK>', 'داره', 'که'): 0.00018565485920881726, ('داره', 'که', 'با'): 8.373745312063257e-06, ('که', 'با', 'روشن'): 8.373745312063257e-06, ('با', 'روشن', 'شدن'): 8.373745312063257e-06, ('روشن', 'شدن', 'گوشی'): 8.373745312063257e-06, ('شدن', 'گوشی', 'بیشتر'): 8.373745312063257e-06, ('گوشی', 'بیشتر', 'هم'): 8.373745312063257e-06, ('بیشتر', 'هم', 'میشه'): 8.373745312063257e-06, ('هم', 'میشه', '</s>'): 8.373745312063257e-06, ('میشه', '</s>', '<s>'): 0.0006420549983176896, ('<s>', '<s>', 'و'): 0.0006420549983176896, ('<s>', 'و', 'نکته'): 8.373745312063257e-06, ('و', 'نکته', 'دیگه'): 8.373745312063257e-06, ('نکته', 'دیگه', 'اینکه'): 8.373745312063257e-06, ('دیگه', 'اینکه', 'به'): 8.373745312063257e-06, ('اینکه', 'به', 'خاطر'): 8.373745312063257e-06, ('به', 'خاطر', 'این'): 8.373745312063257e-06, ('خاطر', 'این', 'که'): 8.373745312063257e-06, ('این', 'که', '<UNK> ...

# %% [markdown]
# # **Perplexity**

# %%
def calculate_perplexity(sentence: list, n_gram_counts: dict, flag=True):
    n = len(list(n_gram_counts.keys())[0])

    if flag:
      sentence = ["<s>"] * n + sentence + ["</s>"]
      words = [sub_sentence.split() for sub_sentence in sentence]
      words = list(chain.from_iterable(words))
    else:
      words = sentence

    words = tuple(words)
    N = len(words)

    product_pi = 1.0
    for t in range(n, N):
        n_gram = words[t - n: t]
        word = words[t]

        probability = estimate_probability(word=word, previous_n_gram=n_gram, n_gram_counts=n_gram_counts)
        product_pi *= 1/probability

    perplexity = product_pi**(1/N)
    return perplexity

# %%
sentence_test  = [
    ["این لپ تاپ سخت افزار خیلی قوی داره و از پس هرکاری به راحتی بر میاد"],
    ["این ساعت بسیار زیبا طراحی و ساخته شده"],
    ["یک محصول با کیفیت ایرانی که حقیقتا جای حمایت داره"],
    ["بوش و ماندگاری خوب هست من خیلی دوستش دارم"]
]

for sentence in sentence_test:
    print("\nSentence:", sentence)
    # perplexity unigram
    unigram_perplexity = calculate_perplexity(sentence, unigrams)
    print("Unigram Perplexity:", unigram_perplexity)

    # perplexity bigram
    bigram_perplexity = calculate_perplexity(sentence, bigrams)
    print("Bigram Perplexity:", bigram_perplexity)

    # perplexity trigram
    trigram_perplexity = calculate_perplexity(sentence, trigrams)
    print("Trigram Perplexity:", trigram_perplexity)
# Out:
# Sentence: ['این لپ تاپ سخت افزار خیلی قوی داره و از پس هرکاری به راحتی بر میاد']
# Unigram Perplexity: 390.5734340154642
# Bigram Perplexity: 1.973494497353576
# Trigram Perplexity: 1.2504054780129021
#
# Sentence: ['این ساعت بسیار زیبا طراحی و ساخته شده']
# Unigram Perplexity: 196.14585947745513
# Bigram Perplexity: 1.8619803457113262
# Trigram Perplexity: 1.2179602608167037
#
# Sentence: ['یک محصول با کیفیت ایرانی که حقیقتا جای حمایت داره']
# Unigram Perplexity: 247.90061462679748
# Bigram Perplexity: 1.9019759019782352
# Trigram Perplexity: 1.2294500418365617
#
# Sentence: ['بوش و ماندگاری خوب هست من خیلی دوستش دارم']
# Unigram Perplexity: 175.646936278939
# Bigram Perplexity: 1.8835390615058878
# Trigram Perplexity: 1.2241336589080962

# %% [markdown]
# # **Predict word**

# %%
import random

def suggest_sentence(sentence, n_gram_models, n_gram_probabilities, num_words=12):
    random.seed(50)
    suggested_sentence = sentence.copy()
    n_gram_order = len(list(n_gram_models.keys())[0])
    suggested_words = set()

    while len(suggested_sentence) < num_words:
        # Determine the context based on the n-gram order
        if n_gram_order == 1:
            context = ()
        elif n_gram_order == 2:
            context = tuple(suggested_sentence[-1:])
        elif n_gram_order == 3:
            context = tuple(suggested_sentence[-2:])

        # Get the probabilities for the next word based on the context
        prob_dist = n_gram_probabilities

        # Get the possible next words and their probabilities
        possible_next_words = [ngram[-1] for ngram in prob_dist.keys() if ngram[:-1] == context and ngram[-1] not in ['<s>', '</s>']]
        next_word_probs = [prob_dist[ngram] for ngram in prob_dist.keys() if ngram[:-1] == context and ngram[-1] not in ['<s>', '</s>']]

        # Choose the next word based on the probabilities
        if next_word_probs:
            # Find the indices of the top 6 probabilities
            top_indices = sorted(range(len(next_word_probs)), key=lambda i: next_word_probs[i], reverse=True)[:6]

            # Randomly select one of the top 6 words
            next_word_index = random.choice(top_indices)
            next_word = possible_next_words[next_word_index]

            # Check if the suggested word has already been suggested
            while next_word in suggested_words:
                top_indices.remove(next_word_index)
                if top_indices:
                    next_word_index = random.choice(top_indices)
                    next_word = possible_next_words[next_word_index]
                else:
                    break

            # Add the suggested word to the suggested words set
            suggested_words.add(next_word)
        else:
            # If there are no words for the given context, break the loop
            break

        # Append the next word to the suggested sentence
        suggested_sentence.append(next_word)

    return suggested_sentence

# %%
def convert_oov(sentence):
  words = []
  for word in sentence:
    flag = 0
    for uni, count in unigrams.items():
      if uni[0] == word:
        flag = 1
        words.append(word)
        break
    if flag == 0:
      words.append('<UNK>')
  return words

# %% [markdown]
# # **Show Suggests and Perplexity**

# %%
sentence_test  = [
    ["کیفیت محصولات چینی زرین"],
    ["از لحاظ جنس جنس خوبی داره"],
    ["حتما پیشنهاد میکنم"],
    ["بعد از چند روز استفاده"]
]

for sentence in sentence_test:
  words_list = [sub_sentence.split() for sub_sentence in sentence]
  words_list = list(chain.from_iterable(words_list))
  words_list = convert_oov(words_list)

  print("\nSentence:", sentence)
  unigram_suggestion = suggest_sentence(words_list, unigrams, unigram_prob)
  print("\nUnigram suggestion:")
  for i, item in enumerate(unigram_suggestion, start=1):
        print(f"{i}. {item}")
  print("Perplexity: ", calculate_perplexity(unigram_suggestion, unigrams, False))


  bigram_suggestion = suggest_sentence(words_list, bigrams, bigram_prob)
  print("\nBigram suggestion:")
  for i, item in enumerate(bigram_suggestion, start=1):
        print(f"{i}. {item}")
  print("Perplexity: ", calculate_perplexity(bigram_suggestion, bigrams, False))

  trigram_suggestion = suggest_sentence(words_list, trigrams, trigram_prob)
  print("\nTrigram suggestion:")
  for i, item in enumerate(trigram_suggestion, start=1):
        print(f"{i}. {item}")
  print("Perplexity: ", calculate_perplexity(trigram_suggestion, trigrams, False))
# Out:
# Sentence: ['کیفیت محصولات چینی زرین']
#
# Unigram suggestion:
# 1. کیفیت
# 2. محصولات
# 3. چینی
# 4. <UNK>
# 5. که
# 6. از
# 7. و
# 8. به
# 9. <UNK>
# 10. این
# 11. این
# 12. به
# Perplexity:  54.37351766214306
#
# Bigram suggestion:
# 1. کیفیت
# 2. محصولات
# 3. چینی
# 4. <UNK>
# 5. باشه
# 6. کامل
# 7. اما
# 8. وقتی
# 9. با
# 10. تنظیمات
# 11. <UNK>
# 12. هست
# Perplexity:  1.8835390615058878
#
# Trigram suggestion:
# 1. کیفیت
# 2. محصولات
# 3. چینی
# 4. <UNK>
# 5. مدل
# 6. <UNK>
# 7. رو
# 8. خرید
# 9. ک
# 10. <UNK>
# 11. باتری
# 12. داد
# Perplexity:  1.2179602608167037
#
# Sentence: ['از لحاظ جنس جنس خوبی داره']
#
# Unigram suggestion:
# 1. از
# 2. لحاظ
# 3. جنس
# 4. جنس
# 5. خوبی
# 6. داره
# 7. که
# 8. از
# 9. و
# 10. به
# 11. <UNK>
# 12. این
# Perplexity:  87.29164571022395
#
# Bigram suggestion:
# 1. از
# 2. لحاظ
# 3. جنس
# 4. جنس
# 5. خوبی
# 6. داره
# 7. دسته
# 8. همیشه
# 9. <UNK>
# 10. جدید
# 11. اون
# 12. قیمت
# Perplexity:  1.8835390615058878
#
# Trigram suggestion:
# 1. از
# 2. لحاظ
# 3. جنس
# 4. جنس
# 5. خوبی
# 6. داره
# 7. شبیه
# 8. پرفیوم
# 9. <UNK>
# 10. <UNK>
# 11. که
# 12. خیلی
# Perplexity:  1.2179602608167037
#
# Sentence: ['حتما پیشنهاد میکنم']
#
# Unigram suggestion:
# 1. حتما
# 2. پیشنهاد
# 3. میکنم
# 4. که
# 5. از
# 6. و
# 7. به
# 8. <UNK>
# 9. این
# 10. این
# 11. به
# 12. و
# Perplexity:  45.704728836407014
#
# Bigram suggestion:
# 1. حتما
# 2. پیشنهاد
# 3. میکنم
# 4. و
# 5. همه
# 6. جای
# 7. <UNK>
# 8. عالیه
# 9. هم
# 10. میشه
# 11. گفت
# 12. برای
# Perplexity:  1.8835390615058878
#
# Trigram suggestion:
# 1. حتما
# 2. پیشنهاد
# 3. میکنم
# 4. به
# 5. هیچ
# 6. وجه
# 7. محدود
# 8. نمیکنه
# 9. کیفیت
# 10. <UNK>
# 11. هم
# 12. راه
# Perplexity:  1.2179602608167037
#
# Sentence: ['بعد از چند روز استفاده']
#
# Unigram suggestion:
# 1. بعد
# 2. از
# 3. چند
# 4. روز
# 5. استفاده
# 6. که
# 7. از
# 8. و
# 9. به
# 10. <UNK>
# 11. این
# 12. این
# Perplexity:  58.27570626182606
#
# Bigram suggestion:
# 1. بعد
# 2. از
# 3. چند
# 4. روز
# 5. استفاده
# 6. بدون
# 7. دردسر
# 8. موهای
# 9. معمولی
# 10. <UNK>
# 11. جدید
# 12. اون
# Perplexity:  1.8835390615058878
#
# Trigram suggestion:
# 1. بعد
# 2. از
# 3. چند
# 4. روز
# 5. استفاده
# 6. <UNK>
# 7. درد
# 8. شدم
# Perplexity:  1.178585061400729

# %% [markdown]
# # **3. POS tagging**
#
# ---

# %%
tagger = POSTagger(model='/content/pos_tagger.model')
tagged_dataset = [[tagger.tag(sentence.split()) for sentence in sublist] for sublist in sentences]

for sentence_tags in tagged_dataset:
    print(sentence_tags)
# Out:
# [[('نسبت', 'NOUN'), ('به', 'ADP'), ('قیمتش', 'NOUN'), ('ارزش', 'NOUN,EZ'), ('خرید', 'NOUN'), ('داره', 'VERB'), ('جاداره', 'NOUN,EZ'), ('طراحیش', 'NOUN'), ('قشنگه', 'VERB'), ('تنها', 'ADV'), ('مشکلش', 'NOUN'), ('بندهای', 'NOUN,EZ'), ('ضعیفش', 'ADJ'), ('هست', 'VERB'), ('که', 'SCONJ'), ('باعث', 'ADJ,EZ'), ('میشه', 'NOUN'), ('استحکام', 'NOUN,EZ'), ('چندانی', 'ADJ'), ('نداشنه', 'VERB'), ('باشه', 'VERB')]]
# [[('چند', 'DET'), ('ماهی', 'NOUN'), ('میشه', 'VERB'), ('که', 'SCONJ'), ('گرفتمش', 'VERB')], [('برای', 'ADP,EZ'), ('برنامه', 'NOUN,EZ'), ('نویسی', 'NOUN'), ('و', 'CCONJ'), ('کارای', 'NOUN,EZ'), ('گرافیکی', 'ADJ'), ('ازش', 'ADP'), ('استفاده', 'NOUN'), ('میکنم', 'VERB')], [('واقعا', 'ADV'), ('از', 'ADP'), ('هر', 'DET'), ('لحاظ', 'NOUN'), ('بگین', 'NOUN'), ('عالیه', 'ADJ')]]
# [[('پراید', 'NOUN,EZ'), ('ستون', 'NOUN,EZ'), ('جدید', 'ADJ')]]
# [[('اقا', 'NOUN'), ('همه', 'DET,EZ'), ('چیش', 'NOUN'), ('خوبه', 'VERB'), ('فقط', 'ADV'), ('از', 'ADP'), ('پایین', 'ADV'), ('زیاد', 'ADJ,EZ'), ('حاشیه', 'NOUN'), ('داره', 'VERB'), ('که', 'SCONJ'), ('با', 'ADP'), ('روشن', 'ADJ'), ('شدن', 'NOUN,EZ'), ('گوشی', 'NOUN,EZ'), ('بیشتر', 'ADJ'), ('هم', 'CCONJ'), ('میشه', 'NOUN')], [('و', 'CCONJ'), ('نکته', 'NOUN,EZ'), ('دیگه', 'ADV'), ('اینکه', 'CCONJ'), ('به', 'ADP'), ('خاطر', 'NOUN,EZ'), ('این', 'PRON'), ('که', 'SCONJ'), ('اطرافش', 'NOUN'), ('یه', 'NUM'), ('کوچلو', 'NOUN'), ('خمیده', 'VERB'), ('هست', 'VERB'), ('گلس', 'NOUN'), ('بعد', 'ADP'), ('یه', 'NUM'), ('مدتی', 'NOUN'), ('جدا', 'ADJ'), ('مشیه', 'NOUN')], [('ولی', 'CCONJ'), ('در', 'ADP'), ('کل', 'NOUN'), ('با', 'ADP'), ('این', 'DET'), ('قیمت', 'NOUN'), ('بهترین', 'ADJ'), ('گوشی', 'NOUN'), ('هست', 'VERB'), ('و', 'CCONJ'), ('همه', 'PRON'), ('چی', 'ADV'), ('داره', 'VERB'), ('از', 'ADP'), ('دوربین', 'NOUN'), ('گرفته', 'VERB'), ('تا', 'ADP'), ('رم', 'NOUN'), ('و', 'CCONJ'), ('سی', 'NUM'), ('پی', 'NOUN,EZ'), ('یو', 'NOUN'), ('و', 'CCONJ'), ('گرافیک', 'NOUN'), ('و', 'CCONJ'), ('حسگر', 'NOUN,EZ'), ('های', 'NOUN,EZ'), ('مختلف', 'ADJ'), ('و', 'CCONJ'), ('خیلی', 'ADV'), ('چیزای', 'VERB'), ('دیگه', 'ADV')]]
# [[('گوسی', 'NOUN'), ('هو', 'NOUN'), ('اوی', 'NOUN'), ('p10', 'NOUN'), ('lite', 'NOUN'), ('سیپیو', 'NOUN'), ('و', 'CCONJ'), ('دوربین', 'NOUN'), ('و', 'CCONJ'), ('رمش', 'NOUN'), ('از', 'ADP'), ('این', 'PRON'), ('خیلی', 'ADV'), ('بهتره', 'VERB'), ('خودتون', 'PRON'), ('میتونین', 'NOUN,EZ'), ('برین', 'ADJ'), ('تمام', 'DET,EZ'), ('مقایسه', 'NOUN,EZ'), ('های', 'NOUN'), ('p10', 'NOUN'), ('liteو', 'NOUN'), ('این', 'DET'), ('گوشیو', 'NOUN'), ('ببینین', 'VERB')]]
# [[('چادر', 'NOUN,EZ'), ('سبک', 'ADJ'), ('و', 'CCONJ'), ('زیباییه', 'NOUN,EZ'), ('دوختشم', 'NOUN,EZ'), ('عالیه', 'ADJ')], [('جنسشم', 'NOUN'), ('خیلی', 'ADV'), ('خوبه', 'VERB'), ('چروک', 'NOUN'), ('نمیشه', 'VERB')]]
# [[('خیلی', 'ADV'), ('خوبه', 'VERB')], [('حتما', 'ADV'), ('پیشنهاد', 'NOUN'), ('میکنم', 'VERB')]]
# [[('من', 'PRON'), ('چند', 'DET'), ('روزیه', 'NOUN'), ('این', 'DET'), ('خردکن', 'NOUN'), ('رو', 'ADP'), ('گرفتم', 'VERB')], [('واقعا', 'ADV'), ('کارکرد', 'NOUN,EZ'), ('خوبی', 'ADJ'), ('دارهطراحی', 'NOUN'), ('ظاهر', 'NOUN,EZ'), ('خردکن', 'ADJ'), ('هم', 'CCONJ'), ('به', 'ADP'), ('نسبت', 'NOUN,EZ'), ('بقیه', 'NOUN,EZ'), ('خردکن', 'NOUN'), ('ها', 'NOUN'), ('خیلی', 'ADV'), ('زیباتره', 'NOUN')], [('تیغه', 'NOUN,EZ'), ('های', 'NOUN'), ('بسیار', 'ADV'), ('تیزی', 'ADJ'), ('داره', 'VERB'), ('که', 'SCONJ'), ('اگه', 'SCONJ'), ('موقع', 'NOUN'), ('شستن', 'NOUN,EZ'), ('حواستون', 'NOUN'), ('نباشه', 'VERB'), ('خیلی', 'ADV'), ('راحت', 'ADV'), ('دستتون', 'NOUN'), ('رو', 'ADP'), ('میبرهجنس', 'NOUN'), ('کاسه', 'NOUN'), ('و', 'CCONJ'), ('تیغه', 'NOUN'), ('هم', 'CCONJ'), ('که', 'SCONJ'), ('خیلی', 'ADV'), ('با', 'ADP'), ('کیفیت', 'NOUN,EZ'), ('هستش', 'NOUN')], [('پیازگوجهگردو', 'NOUN'), ('و', 'CCONJ')], [('رو', 'NOUN'), ('خوب', 'ADJ,EZ'), ('خرد', 'NOUN'), ('میکنهدوستان', 'NOUN'), ('باید', 'VERB'), ('حواسمون', 'NOUN'), ('باشه', 'VERB'), ('این', 'DET'), ('محصول', 'NOUN'), ('خردکن', 'NOUN'), ('هستش', 'VERB'), ('و', 'CCONJ'), ('آسیاب', 'NOUN'), ('نیست', 'VERB'), ('و', 'CCONJ'), ('نباید', 'VERB'), ('انتظار', 'NOUN,EZ'), ('خرد', 'ADJ'), ('کردن', 'NOUN,EZ'), ('موادی', 'NOUN'), ('مثل', 'ADV,EZ'), ('گردو', 'NOUN'), ('رو', 'ADP'), ('در', 'ADP'), ('حد', 'NOUN,EZ'), ('آسیاب', 'NOUN'), ('داشته', 'VERB'), ('باشیم', 'VERB')], [('محصول', 'NOUN,EZ'), ('ساخت', 'NOUN,EZ'), ('کشور', 'NOUN,EZ'), ('ترکیه', 'NOUN'), ('بوده', 'VERB'), ('و', 'CCONJ'), ('تحت', 'ADP,EZ'), ('لیسانس', 'NOUN,EZ'), ('کشور', 'NOUN,EZ'), ('هلند', 'NOUN'), ('هستششکر', 'NOUN,EZ'), ('خدا', 'NOUN'), ('چینی', 'ADJ'), ('نیست', 'VERB')], [('در', 'ADP'), ('کل', 'NOUN,EZ'), ('محصول', 'NOUN'), ('خوبیه', 'VERB'), ('و', 'CCONJ'), ('اگه', 'SCONJ'), ('با', 'ADP'), ('قیمتش', 'NOUN'), ('مشکلی', 'NOUN'), ('ندارین', 'VERB'), ('حتما', 'ADV'), ('پیشنهاد', 'NOUN'), ('میکنم', 'VERB'), ('بخرین', 'ADJ')]]
# [[('این', 'DET'), ('گردن', 'NOUN'), ('اویز', 'NOUN'), ('برای', 'ADP,EZ'), ('هدیه', 'NOUN,EZ'), ('گرفتمراضی', 'ADJ'), ('هستم', 'VERB'), ('ساخت', 'NOUN,EZ'), ('خوبی', 'ADJ'), ('دارهبسیار', 'NOUN,EZ'), ('ظریف', 'ADJ,EZ'), ('وتمیز', 'ADJ'), ('کار', 'NOUN'), ('شده', 'VERB'), ('از', 'ADP'), ('خریدم', 'NOUN'), ('راضی', 'ADJ'), ('هستم', 'VERB')]]
# [[('بسیار', 'ADV'), ('عالی', 'ADJ')]]
# [[('سلام', 'NOUN,EZ'), ('کفش', 'NOUN,EZ'), ('سبکی', 'ADJ'), ('هستش', 'VERB'), ('ولی', 'CCONJ'), ('از', 'ADP'), ('جنس', 'NOUN,EZ'), ('پلاستیک', 'NOUN,EZ'), ('خوبی', 'ADJ'), ('ساخته', 'VERB'), ('نشده', 'VERB'), ('و', 'CCONJ'), ('بوی', 'NOUN,EZ'), ('بسیار', 'ADV'), ('بدی', 'ADJ'), ('میده', 'VERB'), ('نمیدونم', 'VERB'), ('چرا', 'ADV'), ('پشت', 'ADP,EZ'), ('پای', 'NOUN,EZ'), ('منو', 'PRON'), ('میزنه', 'VERB'), ('خیلی', 'ADV'), ('راحت', 'ADJ'), ('نیست', 'VERB'), ('در', 'ADP'), ('کل', 'NOUN'), ('اگر', 'SCONJ'), ('از', 'ADP'), ('نزدیک', 'NOUN'), ('میدیم', 'VERB'), ('اصلا', 'ADV'), ('نمی', 'VERB'), ('خریدمش', 'NOUN')]]
# [[('به', 'ADP'), ('عنوان', 'NOUN,EZ'), ('یه', 'NUM'), ('منتقد', 'NOUN,EZ'), ('بیطرف', 'ADJ'), ('میگم', 'VERB'), ('انصافا', 'ADV'), ('با', 'ADP'), ('این', 'DET'), ('قیمت', 'NOUN'), ('بالا', 'ADV'), ('امکانات', 'NOUN,EZ'), ('متوسطی', 'ADJ'), ('داره', 'VERB')]]
# [[('برای', 'ADP,EZ'), ('من', 'PRON'), ('بعد', 'ADP'), ('از', 'ADP'), ('یک', 'NUM'), ('ماه', 'NOUN'), ('دیگه', 'ADV'), ('کامل', 'ADJ,EZ'), ('شارژ', 'NOUN,EZ'), ('نمی', 'NOUN'), ('شه', 'NOUN'), ('و', 'CCONJ'), ('10', 'NUM'), ('ساعت', 'NOUN,EZ'), ('طول', 'NOUN,EZ'), ('می', 'NOUN,EZ'), ('کشه', 'NOUN'), ('نصف', 'NUM,EZ'), ('بشه', 'NOUN,EZ'), ('شارژش', 'NOUN')]]
# [[('خیلی', 'ADV'), ('واقعا', 'ADV'), ('ناراضیم', 'VERB'), ('با', 'ADP'), ('اینکه', 'CCONJ'), ('خیلیا', 'NOUN'), ('گفتن', 'NOUN'), ('چقدر', 'ADV'), ('کیبوردت', 'NOUN,EZ'), ('خوشگله', 'ADJ')], [('وقتی', 'SCONJ'), ('بهش', 'ADP'), ('عادت', 'NOUN,EZ'), ('میکنی', 'NOUN,EZ'), ('کیبوردای', 'NOUN,EZ'), ('دیگه', 'PRON'), ('رو', 'ADP'), ('نمیتونی', 'VERB'), ('راحت', 'ADV'), ('کار', 'NOUN'), ('کنی', 'VERB'), ('و', 'CCONJ'), ('برعکس', 'ADV')], [('چند', 'DET'), ('تا', 'NOUN'), ('از', 'ADP'), ('کلیدای', 'NOUN,EZ'), ('کیبوردم', 'NOUN'), ('هم', 'CCONJ'), ('خراب', 'ADJ'), ('شده', 'VERB'), ('بعد', 'CCONJ'), ('یکسال', 'ADV'), ('و', 'CCONJ'), ('نیم', 'NUM')], [('خراب', 'ADJ'), ('به', 'ADP'), ('این', 'DET'), ('معنی', 'NOUN'), ('که', 'SCONJ'), ('کج', 'ADJ'), ('شده', 'VERB'), ('زیرش', 'NOUN'), ('و', 'CCONJ'), ('فکر', 'NOUN'), ('کنم', 'VERB'), ('یه', 'NUM'), ('چیزاییش', 'NOUN'), ('شکسته', 'VERB')]]
# [[('خیلی', 'ADV'), ('با', 'ADP'), ('کیفیت', 'NOUN'), ('و', 'CCONJ'), ('باحاله', 'ADJ'), ('البته', 'ADV'), ('اگر', 'SCONJ'), ('به', 'ADP'), ('مرور', 'NOUN,EZ'), ('زمان', 'NOUN,EZ'), ('زرد', 'ADJ'), ('نشه', 'VERB')]]
# [[('دم', 'ADP,EZ'), ('بر', 'NOUN'), ('و', 'CCONJ'), ('بچ', 'NOUN,EZ'), ('ایرانی', 'ADJ'), ('گرم', 'ADJ'), ('که', 'SCONJ'), ('چنین', 'NOUN'), ('وسیله', 'NOUN,EZ'), ('ای', 'NOUN'), ('رو', 'NOUN'), ('ساختن', 'NOUN'), ('برای', 'ADP,EZ'), ('مورچه', 'NOUN'), ('گرفتم', 'VERB'), ('2', 'NUM'), ('هفته', 'NOUN'), ('دارم', 'VERB'), ('استفاده', 'NOUN'), ('میکنم', 'VERB'), ('خیلی', 'ADV'), ('کمتر', 'ADJ'), ('شدن', 'NOUN,EZ'), ('مورچه', 'NOUN,EZ'), ('ها', 'NOUN')]]
# [[('باسلام', 'NOUN'), ('به', 'ADP'), ('نظر', 'NOUN,EZ'), ('من', 'PRON'), ('برای', 'ADP,EZ'), ('پوست', 'NOUN,EZ'), ('های', 'NOUN'), ('چرب', 'ADJ'), ('مناسب', 'ADJ'), ('است', 'VERB'), ('ولی', 'CCONJ'), ('صورت', 'NOUN,EZ'), ('من', 'PRON'), ('که', 'SCONJ'), ('پوستی', 'NOUN'), ('خشک', 'ADJ'), ('دارم', 'VERB'), ('باعث', 'ADJ,EZ'), ('جوش', 'NOUN'), ('شد', 'VERB')]]
# [[('در', 'ADP'), ('پیشنهاد', 'NOUN,EZ'), ('ویژه', 'ADJ,EZ'), ('ارزش', 'NOUN,EZ'), ('خرید', 'NOUN,EZ'), ('دارهدر', 'NOUN'), ('هر', 'DET'), ('اشپزخانه', 'NOUN'), ('ای', 'INTJ'), ('این', 'DET'), ('سه', 'NUM'), ('سایز', 'NOUN,EZ'), ('ماهی', 'NOUN'), ('تابه', 'NOUN'), ('لازم', 'ADJ'), ('هست', 'VERB'), ('از', 'ADP'), ('نظر', 'NOUN,EZ'), ('جنس', 'NOUN'), ('و', 'CCONJ'), ('کیفیت', 'NOUN,EZ'), ('خوب', 'ADJ,EZ'), ('هستاز', 'NOUN,EZ'), ('نظر', 'NOUN,EZ'), ('نگهداری', 'NOUN'), ('مثل', 'ADV,EZ'), ('ظروف', 'NOUN,EZ'), ('تفلون', 'NOUN'), ('ومیباشد', 'VERB')]]
# [[('اصلا', 'ADV'), ('پیشنهاد', 'NOUN'), ('نمی', 'VERB'), ('دهم', 'VERB'), ('چون', 'SCONJ'), ('خیلی', 'ADV'), ('بی', 'ADP'), ('کیفیت', 'NOUN'), ('است', 'VERB')]]
# [[('خیلی', 'ADV'), ('عالیه', 'ADJ'), ('حتما', 'ADV'), ('بگیرید', 'VERB')]]
# [[('قبل', 'ADP'), ('از', 'ADP'), ('خرید', 'NOUN'), ('حتما', 'ADV'), ('گوشی', 'NOUN,EZ'), ('رو', 'NOUN'), ('مغازه', 'NOUN'), ('ببینید', 'VERB'), ('واقعا', 'ADV'), ('از', 'ADP'), ('اینکه', 'CCONJ'), ('نمی', 'VERB'), ('تونه', 'ADV'), ('به', 'ADP'), ('خوبی', 'NOUN,EZ'), ('فیلمهای', 'NOUN,EZ'), ('فول', 'ADJ,EZ'), ('اچ', 'NOUN'), ('دی', 'NOUN'), ('رو', 'ADP'), ('نشون', 'NOUN'), ('بده', 'VERB'), ('نا', 'NOUN'), ('امید', 'NOUN'), ('شدم', 'VERB'), ('بجای', 'NOUN,EZ'), ('نوتیفیکیشن', 'NOUN'), ('قابلیت', 'NOUN,EZ'), ('always', 'NOUN'), ('on', 'NOUN'), ('داره', 'VERB'), ('که', 'SCONJ'), ('پیغامها', 'NOUN'), ('رو', 'ADP'), ('نشون', 'NOUN'), ('می', 'NOUN'), ('ده', 'NUM'), ('رنگ', 'NOUN,EZ'), ('ها', 'NOUN'), ('رو', 'ADP'), ('خوب', 'ADJ,EZ'), ('نشون', 'NOUN'), ('نمی', 'VERB'), ('ده', 'NUM'), ('گوشی', 'NOUN,EZ'), ('قبلی', 'ADJ,EZ'), ('من', 'PRON'), ('LG', 'NOUN'), ('g3', 'NOUN'), ('beat', 'NOUN'), ('بود', 'VERB'), ('و', 'CCONJ'), ('کیفیت', 'NOUN,EZ'), ('صفحه', 'NOUN,EZ'), ('نمایش', 'NOUN,EZ'), ('اون', 'PRON'), ('کجا', 'ADV'), ('و', 'CCONJ'), ('این', 'PRON'), ('کجا', 'ADV')]]
# [[('من', 'PRON'), ('الان', 'ADV'), ('دیماه', 'NOUN'), ('دارم', 'VERB'), ('عاااللییه', 'NOUN,EZ'), ('زیبایی', 'ADJ'), ('بسیار', 'ADV'), ('شگفت', 'ADJ,EZ'), ('انگیز', 'NOUN,EZ'), ('من', 'PRON'), ('طلایی', 'ADJ'), ('رو', 'ADP'), ('دارم', 'VERB'), ('فست', 'NOUN,EZ'), ('شارژ', 'ADJ'), ('تنها', 'ADV'), ('مشکل', 'NOUN,EZ'), ('دوربینش', 'NOUN'), ('12', 'NUM'), ('mp', 'NOUN'), ('هست', 'VERB')]]
# [[('درپیشنهاد', 'NOUN,EZ'), ('ویژه', 'ADJ,EZ'), ('خریدمراضی', 'NOUN,EZ'), ('هستمبسیار', 'NOUN,EZ'), ('کاربردی', 'ADJ'), ('و', 'CCONJ'), ('از', 'ADP'), ('نظر', 'NOUN,EZ'), ('جنس', 'NOUN'), ('و', 'CCONJ'), ('کیفیت', 'NOUN,EZ'), ('ساخت', 'NOUN,EZ'), ('بسیار', 'ADV'), ('خوب', 'ADJ'), ('میباشد', 'VERB')]]
# [[('این', 'DET'), ('لپ', 'NOUN'), ('تاپ', 'NOUN,EZ'), ('سخت', 'ADJ'), ('افزار', 'NOUN,EZ'), ('خیلی', 'ADV'), ('قوی', 'ADJ'), ('داره', 'VERB'), ('واز', 'NOUN'), ('پس', 'ADP'), ('هرکاری', 'NOUN'), ('به', 'ADP'), ('راحتی', 'NOUN'), ('بر', 'ADP'), ('میادحتی', 'NOUN'), ('بازی', 'NOUN,EZ'), ('های', 'NOUN'), ('بروز', 'NOUN,EZ'), ('البته', 'ADV'), ('با', 'ADP'), ('تنظیمات', 'NOUN,EZ'), ('گرافیکی', 'ADJ,EZ'), ('پایین', 'ADJ')], [('ازنظر', 'NOUN,EZ'), ('قابل', 'ADJ,EZ'), ('حمل', 'NOUN'), ('بودن', 'NOUN'), ('هم', 'CCONJ'), ('مشکلی', 'NOUN'), ('نداره', 'VERB'), ('به', 'ADP'), ('علت', 'NOUN,EZ'), ('باریک', 'ADJ,EZ'), ('بودنشاز', 'NOUN,EZ'), ('نظر', 'NOUN,EZ'), ('امکانات', 'NOUN,EZ'), ('خوب', 'ADJ'), ('دیگش', 'PRON'), ('میشه', 'VERB'), ('به', 'ADP'), ('باتری', 'NOUN,EZ'), ('خوبداشتن', 'NOUN,EZ'), ('کیبرد', 'NOUN,EZ'), ('فارسی', 'NOUN'), ('همراه', 'NOUN,EZ'), ('بک', 'NOUN'), ('لایت', 'NOUN'), ('اشاره', 'NOUN'), ('کرد', 'VERB')], [('ازنظرمعایب', 'CCONJ'), ('فقط', 'ADV'), ('دو', 'NUM'), ('مورد', 'NOUN,EZ'), ('میشه', 'NOUN'), ('اشاره', 'NOUN'), ('کرد', 'VERB'), ('که', 'SCONJ'), ('اولا', 'ADV'), ('کیفیت', 'NOUN,EZ'), ('صفحه', 'NOUN,EZ'), ('نمایش', 'NOUN'), ('که', 'SCONJ'), ('خیلی', 'ADV'), ('متوسط', 'ADJ'), ('و', 'CCONJ'), ('دوم', 'ADJ'), ('قسمت', 'NOUN,EZ'), ('تایپ', 'NOUN'), ('و', 'CCONJ'), ('استراحت', 'NOUN'), ('گاه', 'ADV'), ('کیبرد', 'NOUN'), ('که', 'SCONJ'), ('به', 'ADP'), ('دلیل', 'NOUN,EZ'), ('فلزی', 'ADJ'), ('بودن', 'NOUN,EZ'), ('کثیفی', 'ADJ'), ('رو', 'ADP'), ('جزب', 'NOUN'), ('میکنه', 'VERB')], [('باصرف', 'NOUN,EZ'), ('نظر', 'NOUN'), ('از', 'ADP'), ('معایب', 'NOUN'), ('در', 'ADP'), ('صورت', 'NOUN,EZ'), ('اینکه', 'CCONJ'), ('هارد', 'NOUN'), ('این', 'DET'), ('لپتاپ', 'NOUN'), ('رو', 'ADP'), ('به', 'ADP'), ('ssd', 'NOUN'), ('تغییر', 'NOUN,EZ'), ('بدینمیتونیدیکی', 'ADJ'), ('از', 'ADP'), ('قویترین', 'ADJ'), ('کانفیگ', 'NOUN'), ('های', 'NOUN'), ('موجود', 'ADJ'), ('روی', 'ADP,EZ'), ('لب', 'NOUN'), ('تاپ', 'NOUN,EZ'), ('ها', 'NOUN'), ('رو', 'ADP'), ('تجربه', 'NOUN,EZ'), ('کنیددرصورت', 'NOUN'), ('متصل', 'ADJ'), ('بودن', 'NOUN,EZ'), ('لپتاپ', 'NOUN'), ('به', 'ADP'), ('برق', 'NOUN')]]
# [[('فدق', 'NOUN,EZ'), ('العادس', 'NOUN')]]
# [[('فقط', 'ADV'), ('صداش', 'NOUN'), ('یکم', 'NUM'), ('زیاده', 'VERB'), ('ولی', 'CCONJ'), ('واقعا', 'ADV'), ('می', 'NOUN,EZ'), ('ارزه', 'NOUN,EZ'), ('من', 'PRON'), ('تو', 'PRON'), ('شگفت', 'ADJ,EZ'), ('انگیز', 'ADJ'), ('خریدم', 'VERB'), ('چند', 'DET'), ('روزه', 'NOUN'), ('دارم', 'VERB'), ('استفاده', 'NOUN'), ('می', 'NOUN'), ('کنم', 'VERB'), ('تاحالا', 'ADV'), ('که', 'SCONJ'), ('خداروشکر', 'NOUN,EZ'), ('عالیه', 'ADJ')]]
# [[('این', 'DET'), ('گلس', 'NOUN'), ('اصلا', 'ADV'), ('برای', 'ADP,EZ'), ('گوشی', 'NOUN,EZ'), ('j7', 'NOUN,EZ'), ('pro', 'NOUN'), ('2017', 'NUM'), ('نیست', 'VERB'), ('همونجور', 'NOUN'), ('که', 'SCONJ'), ('تو', 'PRON'), ('عکس', 'NOUN'), ('معلومه', 'VERB'), ('این', 'DET'), ('گلس', 'NOUN'), ('برای', 'ADP,EZ'), ('گلکسی', 'NOUN'), ('j7', 'NOUN'), ('2016', 'NUM'), ('هستش', 'NOUN')]]
# [[('این', 'DET'), ('ساعت', 'NOUN'), ('بسیار', 'ADV'), ('زیبا', 'ADJ'), ('طراحی', 'NOUN'), ('و', 'CCONJ'), ('ساخته', 'VERB'), ('شده', 'VERB'), ('و', 'CCONJ'), ('کیفیت', 'NOUN,EZ'), ('ساختش', 'NOUN'), ('کاملا', 'ADV'), ('مشخصه', 'NOUN')], [('ممنون', 'ADJ'), ('از', 'ADP'), ('دیجی', 'ADJ,EZ'), ('کالا', 'NOUN')]]
# [[('نورش', 'NOUN'), ('کمم', 'NOUN'), ('نیست', 'VERB'), ('درسته', 'VERB'), ('مثل', 'ADV,EZ'), ('این', 'DET'), ('شش', 'NUM'), ('واتا', 'NOUN'), ('نور', 'NOUN,EZ'), ('ندارهولی', 'ADJ'), ('قابل', 'ADJ,EZ'), ('قبوله', 'NOUN,EZ'), ('وتو', 'NOUN,EZ'), ('چشم', 'NOUN'), ('نمیزنه', 'VERB'), ('اذیت', 'NOUN,EZ'), ('بشیاز', 'NOUN'), ('دستمم', 'NOUN'), ('افتاد', 'VERB'), ('از', 'ADP'), ('لوستر', 'NOUN'), ('هیچ', 'DET'), ('چیش', 'NOUN'), ('نشدکلا', 'NOUN'), ('خوبه', 'VERB'), ('نسبت', 'NOUN'), ('به', 'ADP'), ('قیمتش', 'NOUN'), ('مفتهنورشم', 'NOUN,EZ'), ('متوسته', 'ADJ'), ('نه', 'ADV'), ('کم', 'ADJ'), ('نه', 'ADV'), ('زیادمن', 'NOUN'), ('که', 'SCONJ'), ('ازش', 'ADP'), ('رازیممثلا', 'NOUN'), ('یه', 'NUM'), ('لوستر', 'NOUN'), ('شش', 'NUM'), ('شعله', 'NOUN'), ('رو', 'ADP'), ('من', 'PRON'), ('سه', 'NUM'), ('تا', 'ADP'), ('از', 'ADP'), ('این', 'DET'), ('محصول', 'NOUN'), ('انداختم', 'VERB'), ('وسه', 'NOUN'), ('تا', 'ADP'), ('هم', 'CCONJ'), ('هفت', 'NUM'), ('وات', 'NOUN'), ('هشت', 'NUM'), ('هزار', 'NUM'), ('تومنی', 'NOUN')]]
# [[('به', 'ADP'), ('نظر', 'NOUN,EZ'), ('من', 'PRON'), ('واقعا', 'ADV'), ('ارزش', 'NOUN,EZ'), ('خریدش', 'NOUN'), ('را', 'ADP'), ('دارهچون', 'NOUN'), ('شما', 'PRON'), ('فقط', 'ADV'), ('پول', 'NOUN,EZ'), ('خود', 'PRON'), ('گوشی', 'NOUN'), ('را', 'ADP'), ('میدید', 'VERB'), ('ولی', 'CCONJ'), ('اگه', 'SCONJ'), ('یه', 'NUM'), ('برند', 'VERB'), ('معروف', 'ADJ'), ('با', 'ADP'), ('همین', 'DET'), ('مشخصات', 'NOUN'), ('بگیرید', 'VERB'), ('باید', 'VERB'), ('بالای', 'ADP,EZ'), ('یه', 'NUM'), ('میلیون', 'NUM'), ('پیاده', 'ADJ'), ('شوید', 'VERB'), ('و', 'CCONJ'), ('بقیه', 'NOUN,EZ'), ('پول', 'NOUN'), ('را', 'ADP'), ('بابت', 'ADP,EZ'), ('برند', 'NOUN'), ('گوشی', 'NOUN'), ('میدید', 'VERB')]]
# [[('من', 'PRON'), ('خرید', 'NOUN'), ('کردم', 'VERB'), ('و', 'CCONJ'), ('بسیار', 'ADV'), ('عالی', 'ADJ'), ('است', 'VERB')]]
# [[('عالی', 'ADJ'), ('و', 'CCONJ'), ('دقیق', 'ADJ'), ('با', 'ADP'), ('فشار', 'NOUN,EZ'), ('سنج', 'ADJ,EZ'), ('جیوه', 'NOUN'), ('ای', 'INTJ'), ('مقایسه', 'NOUN'), ('کردیم', 'VERB'), ('نتیجه', 'NOUN'), ('فرق', 'NOUN'), ('نداشت', 'VERB')]]
# [[('راحت', 'ADV'), ('سفارش', 'NOUN'), ('دادم', 'VERB'), ('خیلی', 'ADV'), ('خوب', 'ADJ'), ('هم', 'CCONJ'), ('تحویل', 'NOUN'), ('گرفتم', 'VERB'), ('پیشنهاد', 'NOUN'), ('میکنم', 'VERB')]]
# [[('اگه', 'SCONJ'), ('زودتر', 'ADV'), ('تلویزیون', 'NOUN'), ('و', 'CCONJ'), ('رادیوشو', 'NOUN'), ('هم', 'CCONJ'), ('راه', 'NOUN,EZ'), ('اندازی', 'NOUN,EZ'), ('کنن', 'NOUN,EZ'), ('عالیه', 'ADJ')]]
# [[('سبک', 'NOUN'), ('و', 'CCONJ'), ('خوشدست', 'ADJ,EZ'), ('راحت', 'ADJ,EZ'), ('میتونی', 'NOUN,EZ'), ('خودت', 'PRON'), ('موهاتو', 'NOUN'), ('در', 'ADP'), ('زمان', 'NOUN,EZ'), ('کوتاه', 'ADJ'), ('صاف', 'ADJ'), ('کنی', 'VERB'), ('دردسر', 'NOUN,EZ'), ('سشوار', 'ADJ'), ('و', 'CCONJ'), ('اتومو', 'NOUN'), ('نداره', 'VERB'), ('ریزش', 'NOUN,EZ'), ('مو', 'NOUN'), ('واقعا', 'ADV'), ('کمتر', 'ADJ'), ('نسبت', 'NOUN'), ('به', 'ADP'), ('سشوار', 'NOUN'), ('بیصدا', 'NOUN'), ('تولید', 'NOUN,EZ'), ('یون', 'NOUN'), ('رو', 'ADP'), ('موهای', 'NOUN,EZ'), ('موجی', 'ADJ'), ('و', 'CCONJ'), ('فر', 'NOUN'), ('امتحان', 'NOUN'), ('کردم', 'VERB'), ('خوب', 'ADV'), ('صاف', 'ADJ'), ('کرد', 'VERB')], [('اگه', 'SCONJ'), ('انتظار', 'NOUN'), ('دارین', 'VERB'), ('موهاتون', 'NOUN'), ('شلاقی', 'NOUN'), ('شه', 'NOUN'), ('خب', 'ADV'), ('باید', 'VERB'), ('با', 'ADP'), ('سشوار', 'NOUN'), ('و', 'CCONJ'), ('اتومو', 'NOUN'), ('بکش', 'VERB'), ('بکش', 'NOUN'), ('کنین', 'VERB'), ('موهاتونو', 'NOUN'), ('و', 'CCONJ'), ('قطعا', 'ADV'), ('آسیب', 'NOUN,EZ'), ('بیشتری', 'ADJ'), ('میرسونه', 'NOUN'), ('به', 'ADP'), ('موهاتون', 'NOUN'), ('واقعا', 'ADV'), ('راضی', 'ADJ'), ('بودم', 'VERB'), ('و', 'CCONJ'), ('هدیه', 'NOUN'), ('هم', 'CCONJ'), ('گرفتم', 'VERB'), ('برای', 'ADP,EZ'), ('مادرم', 'NOUN'), ('ممنون', 'ADJ'), ('دیجیکالا', 'ADJ')]]
# [[('راضی', 'ADJ'), ('بودم', 'VERB')], [('نرم', 'ADJ'), ('میکنه', 'VERB'), ('و', 'CCONJ'), ('واقعا', 'ADV'), ('خوشبوعه', 'NOUN,EZ'), ('حس', 'NOUN,EZ'), ('خوبی', 'ADJ'), ('میده', 'VERB')], [('پیشنهاد', 'NOUN'), ('میکنم', 'VERB'), ('امتحان', 'NOUN,EZ'), ('کنین', 'NOUN')]]
# [[('من', 'PRON'), ('از', 'ADP'), ('دیجی', 'ADJ,EZ'), ('کالا', 'NOUN'), ('یک', 'NUM'), ('نفر', 'NOUN'), ('دیگه', 'PRON'), ('خریده', 'VERB'), ('برام', 'ADP'), ('جنس', 'NOUN,EZ'), ('بدنه', 'NOUN'), ('آنقدر', 'ADV'), ('هم', 'CCONJ'), ('میگن', 'NOUN'), ('بد', 'ADJ'), ('نیست', 'VERB'), ('و', 'CCONJ'), ('مقدار', 'NOUN,EZ'), ('شارژ', 'NOUN'), ('هم', 'CCONJ'), ('خوبه', 'VERB'), ('عالی', 'ADJ'), ('نیست', 'VERB'), ('بهتره', 'NOUN'), ('واقع', 'ADJ'), ('بین', 'ADP,EZ'), ('باشم', 'NOUN')]]
# [[('پوست', 'NOUN'), ('رو', 'ADP'), ('شاداب', 'ADJ'), ('و', 'CCONJ'), ('نرم', 'ADJ'), ('میکنه', 'VERB'), ('تمیزکنندگیشم', 'NOUN,EZ'), ('خیلی', 'ADV'), ('خوبه', 'VERB')]]
# [[('کاورش', 'NOUN'), ('خیلی', 'ADV'), ('خوب', 'ADJ'), ('نبود', 'VERB'), ('و', 'CCONJ'), ('اینکه', 'CCONJ'), ('روشن', 'ADJ'), ('نیس', 'VERB'), ('ولی', 'CCONJ'), ('بد', 'ADJ'), ('هم', 'CCONJ'), ('نیس', 'NOUN'), ('قابل', 'ADJ,EZ'), ('قبوله', 'NOUN')]]
# [[('خریدن', 'NOUN,EZ'), ('ابن', 'NOUN,EZ'), ('تلفن', 'NOUN'), ('همراه', 'NOUN'), ('به', 'ADP'), ('نظرم', 'NOUN'), ('بزرگ', 'ADJ,EZ'), ('ترین', 'ADJ'), ('اشتباهه', 'NOUN')]]
# [[('ماشین', 'NOUN,EZ'), ('من', 'PRON'), ('پرشیاست', 'VERB'), ('وقتی', 'SCONJ'), ('با', 'ADP'), ('سرعت', 'NOUN,EZ'), ('100', 'NUM'), ('حرکت', 'NOUN'), ('میکردم', 'VERB'), ('صدای', 'NOUN,EZ'), ('موتور', 'NOUN,EZ'), ('داخل', 'ADP,EZ'), ('کابین', 'NOUN,EZ'), ('میومد', 'NOUN'), ('خیلی', 'ADV'), ('اعصابمو', 'NOUN'), ('به', 'ADP'), ('هم', 'PRON'), ('ریخته', 'VERB'), ('بود', 'VERB'), ('بیرول', 'NOUN'), ('هم', 'CCONJ'), ('ریختم', 'VERB'), ('ولی', 'CCONJ'), ('فرقی', 'NOUN'), ('نکرد', 'VERB'), ('خواستم', 'VERB'), ('توتال', 'NOUN'), ('هم', 'CCONJ'), ('تست', 'NOUN'), ('کنم', 'VERB'), ('اینو', 'PRON'), ('گرفتم', 'VERB'), ('و', 'CCONJ'), ('ریختم', 'VERB'), ('تو', 'PRON'), ('ماشین', 'NOUN,EZ'), ('دیگه', 'ADV'), ('صدا', 'NOUN'), ('کاملا', 'ADV'), ('قطع', 'NOUN'), ('شد', 'VERB'), ('و', 'CCONJ'), ('تو', 'PRON'), ('سرعت', 'NOUN,EZ'), ('بالا', 'ADJ'), ('دیگه', 'PRON'), ('خیلی', 'ADV'), ('نرم', 'ADJ'), ('کار', 'NOUN'), ('میکنه', 'VERB'), ('موتور', 'NOUN')]]
# [[('واقعا', 'ADV'), ('به', 'ADP'), ('درد', 'NOUN'), ('نمیخوره', 'VERB'), ('یه', 'NUM'), ('نخ', 'NOUN'), ('بستن', 'NOUN'), ('به', 'ADP'), ('کرم', 'NOUN'), ('بعد', 'CCONJ'), ('میگن', 'NOUN,EZ'), ('سحر', 'NOUN,EZ'), ('امیز', 'ADJ')]]
# [[('از', 'ADP'), ('هر', 'DET'), ('نظر', 'NOUN'), ('خوبه', 'VERB')]]
# [[('این', 'DET'), ('خودنویس', 'NOUN'), ('یکی', 'NUM'), ('از', 'ADP'), ('زیباترین', 'ADJ'), ('و', 'CCONJ'), ('دوستداشتنیترین', 'ADJ'), ('خودنویسهای', 'NOUN,EZ'), ('منه', 'NOUN'), ('اما', 'CCONJ'), ('به', 'ADP'), ('خاطر', 'NOUN'), ('پیدا', 'ADJ'), ('نکردن', 'NOUN,EZ'), ('کانورتر', 'ADJ'), ('جوهر', 'NOUN,EZ'), ('فابر', 'NOUN'), ('بیشتر', 'ADJ'), ('از', 'ADP'), ('یکی', 'NUM'), ('دو', 'NUM'), ('ماه', 'NOUN'), ('نتونستم', 'VERB'), ('ازش', 'ADP'), ('استفاده', 'NOUN'), ('کنم', 'VERB'), ('و', 'CCONJ'), ('وقتی', 'SCONJ'), ('کارتریج', 'NOUN'), ('همراه', 'NOUN,EZ'), ('خودنویس', 'NOUN'), ('تموم', 'ADJ'), ('شد', 'VERB'), ('خودنویس', 'NOUN'), ('هم', 'CCONJ'), ('بیاستفاده', 'VERB'), ('موند', 'NOUN')], [('متأسفانه', 'ADV'), ('لوازم', 'NOUN,EZ'), ('جانبی', 'ADJ,EZ'), ('خودنویسهای', 'NOUN,EZ'), ('فابر', 'NOUN'), ('از', 'ADP'), ('قبیل', 'NOUN,EZ'), ('کارتریج', 'NOUN'), ('یا', 'CCONJ'), ('کانورتر', 'ADJ'), ('پمپ', 'NOUN,EZ'), ('جوهر', 'NOUN,EZ'), ('قابل', 'ADJ,EZ'), ('شارژ', 'NOUN'), ('در', 'ADP'), ('ایران', 'NOUN'), ('کمیاب', 'ADJ'), ('و', 'CCONJ'), ('حتی', 'ADV'), ('میشه', 'NOUN'), ('گفت', 'VERB'), ('نایابه', 'NOUN')], [('امیدوارم', 'VERB'), ('دیجیکالا', 'ADV'), ('این', 'DET'), ('مشکل', 'NOUN'), ('رو', 'ADP'), ('هم', 'CCONJ'), ('از', 'ADP'), ('طریق', 'NOUN,EZ'), ('نمایندگیهای', 'NOUN,EZ'), ('محصولات', 'NOUN,EZ'), ('فابرکاستل', 'NOUN'), ('برطرف', 'ADJ'), ('کنه', 'VERB')]]
# [[('واقعا', 'ADV'), ('رم', 'NOUN'), ('خوبیه', 'VERB'), ('خیلی', 'ADV'), ('هم', 'CCONJ'), ('سریع', 'ADJ'), ('است', 'VERB'), ('با', 'ADP'), ('تشکر', 'NOUN'), ('از', 'ADP'), ('دی', 'NOUN'), ('جی', 'NOUN'), ('کالا', 'NOUN')]]
# [[('مال', 'NOUN,EZ'), ('من', 'PRON'), ('بعد', 'ADP'), ('از', 'ADP'), ('3', 'NUM,EZ'), ('ماه', 'NOUN'), ('استفاده', 'NOUN'), ('بدون', 'ADP,EZ'), ('دلیل', 'NOUN,EZ'), ('خاصی', 'ADJ'), ('سوخت', 'VERB')]]
# [[('چند', 'DET'), ('هفته', 'NOUN'), ('ای', 'INTJ'), ('از', 'ADP'), ('خرید', 'NOUN,EZ'), ('این', 'DET'), ('دستگاه', 'NOUN'), ('برای', 'ADP,EZ'), ('من', 'PRON'), ('گذشته', 'VERB'), ('و', 'CCONJ'), ('تا', 'ADP'), ('الان', 'NOUN'), ('که', 'SCONJ'), ('خداروشکر', 'NOUN,EZ'), ('اتفاقی', 'ADJ'), ('نیافتاده', 'VERB'), ('یکی', 'NUM'), ('از', 'ADP'), ('ایراد', 'NOUN,EZ'), ('هایی', 'NOUN'), ('که', 'SCONJ'), ('این', 'DET'), ('دستگاه', 'NOUN'), ('داره', 'VERB'), ('دسته', 'NOUN,EZ'), ('مخزن', 'NOUN,EZ'), ('آب', 'NOUN'), ('هستش', 'VERB'), ('حتی', 'ADV'), ('اگر', 'SCONJ'), ('مخزن', 'NOUN'), ('هم', 'CCONJ'), ('پر', 'ADJ'), ('باشه', 'VERB'), ('دسته', 'NOUN'), ('نمیشکنه', 'VERB'), ('و', 'CCONJ'), ('لی', 'NOUN'), ('از', 'ADP'), ('نوع', 'NOUN,EZ'), ('طراحی', 'NOUN'), ('و', 'CCONJ'), ('پلاستیکی', 'ADJ'), ('بودن', 'NOUN,EZ'), ('جنس', 'NOUN,EZ'), ('دسته', 'NOUN'), ('همیشه', 'ADV'), ('این', 'DET'), ('استرس', 'NOUN'), ('دارین', 'VERB'), ('که', 'SCONJ'), ('یک', 'NUM'), ('موقع', 'NOUN'), ('نشکنه', 'VERB'), ('برای', 'ADP,EZ'), ('همین', 'DET'), ('همیشه', 'ADV'), ('با', 'ADP'), ('دوتا', 'NOUN'), ('دست', 'NOUN'), ('باید', 'VERB'), ('بلند', 'ADJ'), ('کنین', 'VERB'), ('که', 'SCONJ'), ('خاطر', 'NOUN,EZ'), ('جمع', 'NOUN,EZ'), ('باشین', 'ADJ'), ('صدای', 'NOUN,EZ'), ('دستگاه', 'NOUN'), ('کمه', 'VERB'), ('ولی', 'CCONJ'), ('اگر', 'SCONJ'), ('بخواین', 'VERB'), ('کنار', 'ADP,EZ'), ('تخت', 'NOUN,EZ'), ('بیخ', 'NOUN,EZ'), ('گوشتون', 'NOUN,EZ'), ('بزارین', 'ADJ'), ('حتما', 'ADV'), ('شب', 'NOUN,EZ'), ('خوابتون', 'NOUN'), ('نمیبره', 'VERB'), ('من', 'PRON'), ('وسط', 'ADP,EZ'), ('خونه', 'NOUN'), ('گذاشتمش', 'VERB'), ('و', 'CCONJ'), ('قدرت', 'NOUN,EZ'), ('بازدهی', 'NOUN,EZ'), ('فوق', 'ADJ,EZ'), ('العاده', 'NOUN'), ('ای', 'INTJ'), ('داره', 'VERB'), ('چون', 'SCONJ'), ('وقتی', 'SCONJ'), ('دورترین', 'ADJ'), ('نقظه', 'NOUN'), ('خونه', 'NOUN'), ('میره', 'VERB'), ('و', 'CCONJ'), ('یک', 'NUM'), ('شعله', 'NOUN,EZ'), ('گاز', 'NOUN,EZ'), ('روشن', 'ADJ,EZ'), ('میکنی', 'NOUN,EZ'), ('میبینی', 'NOUN'), ('که', 'SCONJ'), ('رنگ', 'NOUN,EZ'), ('اش', 'NOUN,EZ'), ('قرمز', 'ADJ'), ('میشه', 'VERB'), ('که', 'SCONJ'), ('نشون', 'NOUN'), ('میده', 'VERB'), ('وظیفه', 'NOUN,EZ'), ('ش', 'NOUN'), ('درست', 'ADV'), ('انجام', 'NOUN'), ('میده', 'VERB'), ('مساحت', 'NOUN,EZ'), ('منزل', 'NOUN,EZ'), ('ما', 'PRON'), ('250', 'NUM'), ('متری', 'NOUN,EZ'), ('هستش', 'NOUN'), ('در', 'ADP'), ('کل', 'DET,EZ'), ('راضی', 'NOUN,EZ'), ('ام', 'NOUN')]]
# [[('دوستش', 'NOUN'), ('دارم', 'VERB'), ('من', 'PRON'), ('برای', 'ADP,EZ'), ('دختر', 'NOUN,EZ'), ('عمه', 'NOUN'), ('ام', 'NOUN'), ('خریده', 'NOUN'), ('ام', 'NOUN'), ('راضی', 'ADJ'), ('بود', 'VERB')]]
# [[('نسبت', 'NOUN'), ('به', 'ADP'), ('هم', 'CCONJ'), ('قیمت', 'NOUN,EZ'), ('هاش', 'NOUN'), ('واقعا', 'ADV'), ('عالیه', 'ADJ')]]
# [[('یک', 'NUM'), ('محصول', 'NOUN'), ('با', 'ADP'), ('کیفیت', 'NOUN,EZ'), ('ایرانی', 'ADJ'), ('که', 'SCONJ'), ('حقیقتا', 'ADV'), ('جای', 'NOUN,EZ'), ('حمایت', 'NOUN'), ('داره', 'VERB')], [('راه', 'NOUN,EZ'), ('اندازی', 'NOUN'), ('و', 'CCONJ'), ('پشتیبانی', 'NOUN,EZ'), ('شون', 'NOUN'), ('هم', 'CCONJ'), ('بسیار', 'ADV'), ('عالی', 'ADJ'), ('بود', 'VERB')]]
# [[('هدفن', 'NOUN'), ('خوبیه', 'VERB'), ('کیفیت', 'NOUN,EZ'), ('صدای', 'NOUN,EZ'), ('خوبی', 'ADJ'), ('رو', 'ADP'), ('به', 'ADP'), ('شنونده', 'NOUN'), ('میده', 'VERB'), ('در', 'ADP'), ('حدی', 'NOUN'), ('که', 'SCONJ'), ('خوابم', 'NOUN'), ('بگیره', 'VERB'), ('با', 'ADP'), ('هدفن', 'NOUN'), ('میخوابم', 'VERB'), ('شارژ', 'NOUN,EZ'), ('خیلی', 'ADV'), ('خوب', 'ADJ'), ('نگه', 'NOUN'), ('میداره', 'VERB')], [('برد', 'NOUN,EZ'), ('بلوتوث', 'NOUN'), ('هم', 'CCONJ'), ('بستگی', 'NOUN'), ('به', 'ADP'), ('فرستنده', 'NOUN'), ('هم', 'CCONJ'), ('داره', 'VERB'), ('با', 'ADP'), ('یه', 'NUM'), ('گوشی', 'NOUN,EZ'), ('داغون', 'ADJ'), ('گوش', 'NOUN,EZ'), ('بدی', 'NOUN,EZ'), ('خوب', 'ADJ'), ('معلومه', 'VERB'), ('10', 'NUM'), ('متر', 'NOUN'), ('هم', 'CCONJ'), ('جواب', 'NOUN'), ('نمیده', 'VERB'), ('من', 'PRON'), ('تا', 'ADP'), ('20', 'NUM'), ('متر', 'NOUN'), ('بدون', 'ADP,EZ'), ('قطعی', 'ADJ'), ('ازش', 'ADP'), ('استفاده', 'NOUN'), ('کردم', 'VERB'), ('درکل', 'ADV'), ('از', 'ADP'), ('خریدم', 'NOUN'), ('راضی', 'ADJ'), ('هستم', 'VERB')]]
# [[('باید', 'VERB'), ('چند', 'DET'), ('بار', 'NOUN'), ('رو', 'ADP'), ('ناخن', 'NOUN'), ('کشید', 'VERB'), ('تا', 'SCONJ'), ('کاملا', 'ADV'), ('تمیز', 'ADJ,EZ'), ('شه', 'NOUN')], [('به', 'ADP'), ('نظر', 'NOUN'), ('به', 'ADP'), ('ناخن', 'NOUN,EZ'), ('اسیب', 'NOUN'), ('نمیزنه', 'VERB'), ('خشک', 'ADJ'), ('نمیکنه', 'VERB')], [('من', 'PRON'), ('از', 'ADP'), ('بوش', 'NOUN'), ('اصلا', 'ADV'), ('خوشم', 'ADJ'), ('نمیاد', 'VERB'), ('حس', 'NOUN,EZ'), ('فضای', 'NOUN,EZ'), ('بیمارستانی', 'ADJ,EZ'), ('میداد', 'NOUN')], [('چند', 'DET'), ('ساله', 'NOUN'), ('مارک', 'NOUN'), ('farmasi', 'NOUN'), ('استفاده', 'NOUN,EZ'), ('میکنمو', 'NOUN'), ('ترجیحم', 'NOUN'), ('همیشه', 'ADV'), ('همینه', 'VERB')], [('چون', 'SCONJ'), ('قدرت', 'NOUN,EZ'), ('پاککندگیش', 'NOUN'), ('بیشتره', 'VERB'), ('و', 'CCONJ'), ('خوشبوعه', 'ADJ'), ('و', 'CCONJ'), ('اسیبی', 'NOUN'), ('هم', 'CCONJ'), ('به', 'ADP'), ('ناخن', 'NOUN'), ('نمیزنه', 'VERB')]]
# [[('حدود', 'DET,EZ'), ('دو', 'NUM'), ('ماهه', 'NOUN,EZ'), ('شش', 'NUM'), ('عطر', 'NOUN'), ('از', 'ADP'), ('برند', 'NOUN'), ('امپر', 'NOUN'), ('از', 'ADP'), ('دیجی', 'ADJ,EZ'), ('کالا', 'NOUN'), ('خریدم', 'VERB'), ('که', 'SCONJ'), ('از', 'ADP'), ('پنج', 'NUM'), ('تاش', 'NOUN'), ('خیلی', 'ADV'), ('راضیم', 'VERB'), ('اول', 'ADJ'), ('از', 'ADP'), ('veronica', 'NOUN')], [('راضیم', 'NOUN,EZ'), ('بعد', 'NOUN,EZ'), ('legend', 'NOUN')], [('برای', 'ADP,EZ'), ('کسانیکه', 'NOUN'), ('عطر', 'NOUN,EZ'), ('گرم', 'ADJ,EZ'), ('میپسندن', 'NOUN,EZ'), ('یه', 'NUM'), ('عطر', 'NOUN,EZ'), ('فوق', 'ADJ,EZ'), ('العاده', 'NOUN'), ('خوشبوئیه', 'NOUN'), ('بوی', 'NOUN,EZ'), ('یاسش', 'NOUN'), ('آدمو', 'NOUN'), ('میبره', 'NOUN'), ('به', 'ADP'), ('سالهای', 'NOUN,EZ'), ('دور', 'ADJ'), ('و', 'CCONJ'), ('پیچکهای', 'NOUN,EZ'), ('یاس', 'NOUN'), ('خانه', 'NOUN,EZ'), ('پدری', 'NOUN')], [('عاشق', 'ADJ,EZ'), ('این', 'DET'), ('عطرم', 'NOUN')], [('ممنون', 'ADJ'), ('از', 'ADP'), ('دیجی', 'ADJ,EZ'), ('کالا', 'NOUN')]]
# [[('سیم', 'NOUN,EZ'), ('مشکیدرکل', 'NOUN'), ('بدنیست', 'VERB'), ('پیشنهادمیکنم', 'NOUN,EZ'), ('توشگفت', 'ADJ,EZ'), ('انگیزخریدکنیدموفق', 'ADJ'), ('باشیــــــــد', 'VERB')]]
# [[('کیفیت', 'NOUN,EZ'), ('صدای', 'NOUN,EZ'), ('خوبی', 'ADJ'), ('داره', 'VERB'), ('و', 'CCONJ'), ('مقاومه', 'NOUN'), ('ولی', 'CCONJ'), ('چیزی', 'NOUN'), ('که', 'SCONJ'), ('باعث', 'ADJ'), ('شده', 'VERB'), ('اصلا', 'ADV'), ('راضی', 'ADJ'), ('نباشم', 'VERB'), ('از', 'ADP'), ('خریدش', 'NOUN'), ('اندازه', 'NOUN'), ('شه', 'NOUN,EZ'), ('محصول', 'NOUN'), ('از', 'ADP'), ('چیزی', 'NOUN'), ('که', 'SCONJ'), ('توی', 'ADP,EZ'), ('عکس', 'NOUN'), ('به', 'ADP'), ('نظر', 'NOUN'), ('میاد', 'VERB'), ('خیلی', 'ADV'), ('خیلی', 'ADV'), ('بزرگتره', 'VERB'), ('و', 'CCONJ'), ('اصلا', 'ADV'), ('اونجوری', 'NOUN'), ('که', 'SCONJ'), ('توی', 'ADP,EZ'), ('عکس', 'NOUN'), ('کشیده', 'VERB'), ('دور', 'ADP,EZ'), ('گوش', 'NOUN'), ('نمیایسته', 'VERB'), ('و', 'CCONJ'), ('روی', 'ADP,EZ'), ('سر', 'NOUN,EZ'), ('کیپ', 'NOUN'), ('نمیشه', 'VERB'), ('به', 'ADP'), ('خاطر', 'NOUN,EZ'), ('اندازه', 'NOUN,EZ'), ('خیلی', 'ADV'), ('بزرگش', 'ADJ')]]
# [[('به', 'ADP'), ('نظرم', 'NOUN'), ('من', 'PRON'), ('Black', 'NOUN'), ('AFghno', 'NOUN'), ('نصف', 'NUM,EZ'), ('این', 'DET'), ('قیمت', 'NOUN'), ('داره', 'VERB'), ('ولی', 'CCONJ'), ('خیلی', 'ADV'), ('بهتره', 'VERB')], [('در', 'ADP'), ('کل', 'NOUN'), ('راضی', 'ADJ'), ('بودم', 'VERB'), ('هدیه', 'NOUN'), ('ای', 'INTJ'), ('بسیار', 'ADV'), ('زیبا', 'ADJ'), ('و', 'CCONJ'), ('فوق', 'ADJ,EZ'), ('العاده', 'NOUN'), ('ای', 'INTJ'), ('برای', 'ADP,EZ'), ('پدرم', 'NOUN'), ('بود', 'VERB')]]
# [[('انقد', 'NOUN,EZ'), ('خوب', 'ADJ'), ('بود', 'VERB'), ('که', 'SCONJ'), ('تا', 'ADP'), ('بابا', 'NOUN'), ('دیدش', 'VERB'), ('ازم', 'CCONJ'), ('گرفت', 'VERB'), ('گفت', 'VERB'), ('برا', 'ADP'), ('من', 'PRON'), ('برو', 'VERB'), ('یکی', 'NUM'), ('دیگه', 'PRON'), ('برا', 'ADP'), ('خودت', 'PRON'), ('بگیرتازه', 'VERB'), ('گوشیشم', 'NOUN,EZ'), ('ایفونه', 'NOUN')]]
# [[('خیلی', 'ADV'), ('عالیه', 'ADJ'), ('از', 'ADP'), ('خریدش', 'NOUN'), ('راضیم', 'VERB')], [('قیمتش', 'NOUN'), ('تو', 'PRON'), ('شگفت', 'ADJ,EZ'), ('انگیز', 'NOUN,EZ'), ('عالی', 'ADJ'), ('بود', 'VERB'), ('و', 'CCONJ'), ('الان', 'ADV'), ('هم', 'CCONJ'), ('با', 'ADP'), ('این', 'DET'), ('قیمت', 'NOUN'), ('واقعا', 'ADV'), ('می', 'NOUN,EZ'), ('ارزه', 'NOUN')], [('فقط', 'ADV'), ('یخورده', 'ADJ,EZ'), ('سنگینه', 'NOUN'), ('که', 'SCONJ'), ('اونم', 'PRON'), ('با', 'ADP'), ('توجه', 'NOUN'), ('به', 'ADP'), ('ظرفیت', 'NOUN,EZ'), ('باتری', 'NOUN,EZ'), ('عادی', 'ADJ'), ('محسوب', 'ADJ'), ('میشه', 'VERB')]]
# [[('وقتی', 'SCONJ'), ('کانال', 'NOUN'), ('عوض', 'NOUN'), ('میکنید', 'VERB'), ('باید', 'VERB'), ('برید', 'VERB'), ('یه', 'NUM'), ('چایی', 'NOUN'), ('دم', 'NOUN'), ('کنید', 'VERB'), ('و', 'CCONJ'), ('برگردید', 'VERB'), ('تا', 'SCONJ'), ('کانال', 'NOUN'), ('عوض', 'NOUN'), ('شده', 'VERB'), ('باشه', 'VERB')], [('خیلی', 'ADV'), ('کنده', 'VERB')], [('یه', 'NUM'), ('ایکس', 'NOUN'), ('ویژن', 'NOUN'), ('شبیه', 'ADJ,EZ'), ('اینو', 'PRON'), ('داشتیم', 'VERB'), ('قبلا', 'ADV'), ('سریعتر', 'ADJ'), ('بود', 'VERB')], [('نمیدونم', 'VERB'), ('چرا', 'ADV'), ('انقدر', 'NOUN'), ('کنده', 'VERB')], [('جای', 'NOUN,EZ'), ('یو', 'NOUN'), ('اس', 'NOUN'), ('بی', 'ADP'), ('هم', 'CCONJ'), ('سفت', 'ADJ'), ('نیست', 'VERB'), ('و', 'CCONJ'), ('وقتی', 'SCONJ'), ('یو', 'NOUN'), ('اس', 'NOUN'), ('بی', 'ADP'), ('میذارم', 'NOUN'), ('و', 'CCONJ'), ('برمیدارم', 'VERB'), ('هر', 'DET'), ('لحظه', 'NOUN'), ('منتظر', 'ADJ,EZ'), ('خراب', 'ADJ'), ('بشه', 'VERB'), ('و', 'CCONJ'), ('از', 'ADP'), ('جاش', 'NOUN'), ('دربیاد', 'NOUN')], [('منوش', 'NOUN'), ('هم', 'CCONJ'), ('قبلا', 'ADV'), ('بهتر', 'ADJ'), ('از', 'ADP'), ('الآن', 'NOUN'), ('بود', 'VERB')]]
# [[('عالیه', 'NOUN')], [('من', 'PRON'), ('خیلی', 'ADV'), ('از', 'ADP'), ('گوشی', 'NOUN,EZ'), ('ها', 'NOUN'), ('را', 'ADP'), ('امتحان', 'NOUN'), ('کردم', 'VERB'), ('انواع', 'NOUN,EZ'), ('هواویاچ', 'NOUN'), ('تی', 'NOUN'), ('سیالجیآیفون', 'NOUN'), ('ولی', 'CCONJ'), ('این', 'DET'), ('از', 'ADP'), ('همش', 'PRON'), ('بهتره', 'VERB'), ('در', 'ADP'), ('خریدش', 'NOUN'), ('شک', 'NOUN'), ('نکنین', 'VERB'), ('من', 'PRON'), ('حدود', 'DET,EZ'), ('9', 'NUM'), ('ماهه', 'NOUN'), ('که', 'SCONJ'), ('دارم', 'VERB'), ('خیلی', 'ADV'), ('بهتر', 'ADJ'), ('از', 'ADP'), ('آیفون', 'NOUN'), ('هاست', 'VERB'), ('و', 'CCONJ'), ('قابلیت', 'NOUN,EZ'), ('های', 'NOUN,EZ'), ('بیشتری', 'ADJ'), ('داره', 'VERB')]]
# [[('با', 'ADP'), ('این', 'DET'), ('قیمتی', 'NOUN'), ('که', 'SCONJ'), ('این', 'DET'), ('گوشی', 'NOUN'), ('داره', 'VERB'), ('به', 'ADP'), ('جاش', 'NOUN'), ('دوگزینه', 'NOUN'), ('بهتر', 'ADJ'), ('هست', 'VERB')], [('اگه', 'SCONJ'), ('55', 'NUM'), ('اینچی', 'NOUN'), ('میخواین', 'NOUN'), ('y7', 'NOUN'), ('prime', 'NOUN'), ('رو', 'ADP'), ('بخرید', 'VERB'), ('که', 'SCONJ'), ('هم', 'CCONJ'), ('دوربین', 'NOUN,EZ'), ('سلفیش', 'NOUN,EZ'), ('8', 'NOUN'), ('هست', 'VERB')], [('هم', 'CCONJ'), ('باطریش', 'NOUN'), ('4000', 'NUM'), ('میلی', 'NOUN'), ('آمپر', 'NOUN'), ('هست', 'VERB')], [('هم', 'CCONJ'), ('اینترنت', 'NOUN'), ('cat6', 'NOUN'), ('داره', 'VERB'), ('و', 'CCONJ'), ('45G', 'NOUN'), ('رو', 'ADP'), ('با', 'ADP'), ('آپلود', 'NOUN,EZ'), ('300', 'NUM'), ('مگ', 'NOUN'), ('پشتیبانی', 'NOUN,EZ'), ('میکنه', 'NOUN')], [('اگه', 'SCONJ'), ('صفحه', 'NOUN,EZ'), ('52', 'NUM,EZ'), ('میخواین', 'NOUN'), ('هم', 'CCONJ'), ('هونور', 'NOUN'), ('8', 'NUM'), ('لایت', 'NOUN'), ('بگیرید', 'VERB'), ('که', 'SCONJ'), ('هم', 'CCONJ'), ('سلفیش', 'NOUN,EZ'), ('8', 'NOUN'), ('هست', 'VERB'), ('و', 'CCONJ'), ('هم', 'CCONJ'), ('صفحش', 'NOUN,EZ'), ('فول', 'NOUN'), ('اچ', 'NOUN'), ('دی', 'NOUN')], [('اما', 'CCONJ'), ('باز', 'ADV'), ('بین', 'ADP,EZ'), ('y7', 'NOUN'), ('prime', 'NOUN'), ('و', 'CCONJ'), ('هونور8', 'NOUN'), ('لایت', 'NOUN'), ('اگه', 'SCONJ'), ('بخواین', 'VERB'), ('انتخاب', 'NOUN,EZ'), ('کنین', 'NOUN'), ('قطعأ', 'NOUN,EZ'), ('y7', 'NOUN'), ('prime', 'NOUN'), ('بهتره', 'VERB')], [('امیدوارم', 'VERB'), ('واسه', 'ADP'), ('انتخاب', 'NOUN'), ('کمکتون', 'NOUN'), ('کرده', 'VERB'), ('باشم', 'VERB')]]
# [[('ما', 'PRON'), ('دو', 'NUM'), ('مدل', 'NOUN'), ('از', 'ADP'), ('این', 'DET'), ('دستگاها', 'NOUN'), ('تو', 'ADP'), ('خونه', 'NOUN'), ('داشتیم', 'VERB'), ('که', 'SCONJ'), ('جفتشون', 'NOUN'), ('بد', 'ADJ'), ('بودن', 'NOUN'), ('اومدم', 'VERB'), ('اینجا', 'ADV'), ('اول', 'ADV'), ('نظراتو', 'NOUN'), ('خوندم', 'VERB'), ('دیدم', 'VERB'), ('راضین', 'NOUN,EZ'), ('بقیه', 'NOUN')], [('منم', 'PRON'), ('سفارش', 'NOUN'), ('دادم', 'VERB'), ('الان', 'ADV'), ('که', 'SCONJ'), ('ازش', 'ADP'), ('استفاده', 'NOUN'), ('کردم', 'VERB'), ('دیدم', 'VERB'), ('واااقعا', 'ADV'), ('عالیه', 'ADJ'), ('هم', 'CCONJ'), ('خود', 'PRON,EZ'), ('محصول', 'NOUN'), ('با', 'ADP'), ('کلاس', 'NOUN'), ('و', 'CCONJ'), ('خوشگل', 'ADJ'), ('و', 'CCONJ'), ('خوش', 'ADJ'), ('دسته', 'NOUN'), ('هم', 'CCONJ'), ('خیلی', 'ADV'), ('راحت', 'ADJ'), ('و', 'CCONJ'), ('بدون', 'ADP,EZ'), ('دردسر', 'NOUN,EZ'), ('موهای', 'NOUN,EZ'), ('بینی', 'NOUN'), ('رو', 'NOUN'), ('اصلاح', 'NOUN'), ('کرد', 'VERB'), ('وظیفه', 'NOUN'), ('دونستم', 'VERB'), ('کامنت', 'NOUN'), ('بزارم', 'VERB')]]
# [[('مهمترین', 'ADJ'), ('قسمت', 'NOUN,EZ'), ('اتو', 'NOUN'), ('کفی', 'NOUN'), ('اون', 'PRON'), ('هست', 'VERB'), ('و', 'CCONJ'), ('کفی', 'NOUN'), ('این', 'DET'), ('اتو', 'NOUN'), ('اصلا', 'ADV'), ('خوب', 'ADJ'), ('نیست', 'VERB')], [('حتی', 'ADV'), ('اگه', 'SCONJ'), ('هفتاد', 'NUM'), ('درصد', 'NOUN'), ('هم', 'CCONJ'), ('تخفیف', 'NOUN'), ('بخوره', 'VERB'), ('ارزش', 'NOUN,EZ'), ('خرید', 'NOUN'), ('نداره', 'VERB')], [('چون', 'SCONJ'), ('اون', 'DET'), ('انتظاری', 'NOUN'), ('که', 'SCONJ'), ('از', 'ADP'), ('یه', 'NUM'), ('اتو', 'NOUN'), ('میره', 'VERB'), ('برآورد', 'NOUN'), ('نمیکنه', 'VERB')]]
# [[('کیفست', 'NOUN,EZ'), ('خوبی', 'ADJ'), ('داره', 'VERB'), ('و', 'CCONJ'), ('بنظرم', 'NOUN'), ('برای', 'ADP,EZ'), ('سفر', 'NOUN,EZ'), ('خیلی', 'DET'), ('مناسبه', 'NOUN'), ('و', 'CCONJ'), ('وزنش', 'NOUN'), ('هم', 'CCONJ'), ('نه', 'ADV'), ('زیاده', 'VERB'), ('و', 'CCONJ'), ('نه', 'ADV'), ('کم', 'ADJ'), ('در', 'ADP'), ('کل', 'NOUN'), ('بنظرم', 'VERB'), ('خیلی', 'ADV'), ('خوبه', 'VERB')]]
# [[('هندزفری', 'NOUN'), ('خیلی', 'ADV'), ('خوب', 'ADJ'), ('و', 'CCONJ'), ('قوی', 'ADJ'), ('ای', 'INTJ'), ('هستشصدا', 'ADV'), ('کاملا', 'ADV'), ('واضح', 'ADJ'), ('و', 'CCONJ'), ('خوبه', 'ADJ'), ('و', 'CCONJ'), ('نقطه', 'NOUN,EZ'), ('قوتش', 'NOUN'), ('بیس', 'NOUN'), ('خیلی', 'ADV'), ('خوبشهراضیم', 'VERB'), ('ازشبرای', 'ADP,EZ'), ('استفاده', 'NOUN,EZ'), ('متوسط', 'ADJ'), ('و', 'CCONJ'), ('روزمره', 'ADJ'), ('خوبه', 'VERB'), ('از', 'ADP'), ('گوشم', 'NOUN'), ('درنمیاد', 'VERB')]]
# [[('به', 'ADP'), ('نظر', 'NOUN,EZ'), ('من', 'PRON'), ('بوی', 'NOUN,EZ'), ('خوب', 'ADJ'), ('و', 'CCONJ'), ('شیک', 'ADJ'), ('و', 'CCONJ'), ('ملایمی', 'ADJ'), ('دارهعطر', 'NOUN,EZ'), ('گل', 'NOUN'), ('و', 'CCONJ'), ('تازگی', 'NOUN')], [('باعث', 'ADJ,EZ'), ('سردرد', 'NOUN'), ('هم', 'CCONJ'), ('نمیشه', 'VERB'), ('و', 'CCONJ'), ('دلیلش', 'NOUN'), ('پخش', 'NOUN'), ('بوی', 'NOUN,EZ'), ('کم', 'ADJ'), ('و', 'CCONJ'), ('البته', 'ADV'), ('لطافت', 'NOUN,EZ'), ('این', 'DET'), ('رایحه', 'NOUN'), ('هست', 'VERB'), ('و', 'CCONJ'), ('اینکه', 'CCONJ'), ('ماندگاریش', 'NOUN'), ('کم', 'ADJ'), ('نیست', 'VERB')], [('من', 'PRON'), ('خیلی', 'ADV'), ('راضیم', 'VERB'), ('از', 'ADP'), ('خریدم', 'VERB'), ('چون', 'SCONJ'), ('دوست', 'NOUN'), ('نداشتم', 'VERB'), ('خیلی', 'ADV'), ('بوی', 'NOUN,EZ'), ('عطر', 'NOUN'), ('پخش', 'NOUN'), ('بشه', 'VERB'), ('در', 'ADP'), ('عین', 'NOUN,EZ'), ('حال', 'NOUN'), ('خودم', 'PRON'), ('کاملا', 'ADV'), ('حس', 'NOUN'), ('میکنم', 'VERB'), ('و', 'CCONJ'), ('اگر', 'SCONJ'), ('کسی', 'NOUN'), ('کنارم', 'VERB'), ('باشه', 'VERB'), ('کامل', 'ADV'), ('متوجه', 'ADJ,EZ'), ('رایحه', 'NOUN,EZ'), ('ی', 'NOUN,EZ'), ('خوب', 'ADJ,EZ'), ('این', 'DET'), ('ادکلن', 'NOUN'), ('میشه', 'NOUN')]]
# [[('من', 'PRON'), ('برای', 'ADP,EZ'), ('سمند', 'NOUN'), ('معمولی', 'ADJ'), ('گرفتم', 'VERB'), ('خیلی', 'ADV'), ('خوشگله', 'ADJ'), ('وضمنا', 'CCONJ'), ('اعث', 'NOUN,EZ'), ('عرق', 'NOUN'), ('کردن', 'NOUN'), ('هم', 'CCONJ'), ('نمیشه', 'VERB')]]
# [[('خیلی', 'ADV'), ('عالیه', 'ADJ')]]
# [[('من', 'PRON'), ('این', 'DET'), ('ساعت', 'NOUN'), ('رو', 'ADP'), ('دست', 'NOUN'), ('کردم', 'VERB'), ('حس', 'NOUN,EZ'), ('این', 'DET'), ('ساعت', 'NOUN'), ('های', 'NOUN'), ('رو', 'ADP'), ('بهتون', 'ADP'), ('میده', 'VERB'), ('که', 'SCONJ'), ('دست', 'NOUN,EZ'), ('فروش', 'NOUN,EZ'), ('ها', 'NOUN'), ('اون', 'PRON'), ('رو', 'ADP'), ('می', 'NOUN,EZ'), ('فروش', 'NOUN,EZ'), ('من', 'PRON'), ('رنگ', 'NOUN,EZ'), ('سبز', 'ADJ,EZ'), ('این', 'DET'), ('کار', 'NOUN'), ('رو', 'ADP'), ('دست', 'NOUN'), ('کردم', 'VERB'), ('به', 'ADP'), ('نظر', 'NOUN,EZ'), ('من', 'PRON'), ('واقعا', 'ADV'), ('ارزش', 'NOUN,EZ'), ('این', 'DET'), ('پول', 'NOUN'), ('رو', 'ADP'), ('نداره', 'VERB')]]
# [[('باتوجه', 'NOUN'), ('به', 'ADP'), ('قیمت', 'NOUN,EZ'), ('خیلی', 'ADV'), ('کم', 'ADJ'), ('این', 'DET'), ('محصول', 'NOUN'), ('و', 'CCONJ'), ('کاربردی', 'ADJ'), ('بودنش', 'NOUN'), ('ارزش', 'NOUN,EZ'), ('خرید', 'NOUN,EZ'), ('بالایی', 'ADJ'), ('داره', 'VERB')]]
# [[('متاسفانه', 'ADV'), ('ساعت', 'NOUN'), ('کارکرد', 'NOUN'), ('نداره', 'VERB'), ('و', 'CCONJ'), ('روزی', 'NOUN'), ('ده', 'NUM'), ('دقیقه', 'NOUN'), ('عقب', 'ADV'), ('میفته', 'VERB')]]
# [[('در', 'ADP'), ('کل', 'NOUN'), ('اگر', 'SCONJ'), ('دنبال', 'NOUN,EZ'), ('یک', 'NUM'), ('آباژور', 'NOUN,EZ'), ('شیک', 'ADJ'), ('می', 'NOUN'), ('گردید', 'VERB'), ('می', 'NOUN,EZ'), ('تونه', 'ADJ'), ('انتخاب', 'NOUN,EZ'), ('خوبی', 'ADJ'), ('باشه', 'VERB')]]
# [[('نسبت', 'NOUN'), ('به', 'ADP'), ('باطری', 'NOUN,EZ'), ('اورجینال', 'NOUN,EZ'), ('خود', 'PRON'), ('گوشی', 'NOUN'), ('حرفی', 'NOUN'), ('برای', 'ADP,EZ'), ('گفتن', 'NOUN'), ('نداره', 'VERB'), ('بسیار', 'ADV'), ('کمتر', 'ADJ'), ('از', 'ADP'), ('ظرفیت', 'NOUN,EZ'), ('اسمیش', 'NOUN'), ('توان', 'NOUN'), ('داره', 'VERB'), ('شاید', 'ADV'), ('در', 'ADP'), ('حد', 'NOUN,EZ'), ('1500', 'NUM'), ('میلی', 'NOUN'), ('آمپر', 'NOUN'), ('به', 'ADP'), ('زور', 'NOUN,EZ'), ('یک', 'NUM'), ('روز', 'NOUN'), ('رو', 'ADP'), ('دوام', 'NOUN'), ('میاره', 'VERB'), ('فابریک', 'NOUN,EZ'), ('خود', 'PRON'), ('گوشی', 'NOUN,EZ'), ('سه', 'NUM'), ('روز', 'NOUN'), ('موندگاری', 'NOUN'), ('داشت', 'VERB'), ('در', 'ADP'), ('بدترین', 'ADJ'), ('شرایط', 'NOUN,EZ'), ('دو', 'NUM'), ('روز', 'NOUN,EZ'), ('کامل', 'ADJ'), ('اما', 'CCONJ'), ('این', 'PRON'), ('در', 'ADP'), ('بهترین', 'ADJ'), ('شرایط', 'NOUN,EZ'), ('یک', 'NUM'), ('روز', 'NOUN'), ('و', 'CCONJ'), ('نیم', 'NUM'), ('بدون', 'ADP,EZ'), ('فشار', 'NOUN'), ('آوردن', 'NOUN,EZ'), ('بهش', 'ADP'), ('دوام', 'NOUN'), ('داره', 'VERB')]]
# [[('گوشی', 'NOUN,EZ'), ('خوش', 'ADJ'), ('دست', 'NOUN'), ('و', 'CCONJ'), ('سبکیه', 'NOUN'), ('و', 'CCONJ'), ('دو', 'NUM'), ('سیم', 'NOUN,EZ'), ('کارت', 'NOUN'), ('هستش', 'VERB')], [('رم', 'NOUN'), ('هم', 'CCONJ'), ('میخورهچراغ', 'NOUN,EZ'), ('قوه', 'NOUN'), ('داره', 'VERB')], [('جنس', 'NOUN,EZ'), ('بدنش', 'NOUN'), ('هم', 'CCONJ'), ('با', 'ADP'), ('کیفیتهطراحی', 'NOUN,EZ'), ('فنلاند', 'NOUN'), ('و', 'CCONJ'), ('ساخت', 'NOUN,EZ'), ('ویتنامهایراد', 'NOUN'), ('خاصی', 'ADJ'), ('نداره', 'VERB'), ('فقط', 'ADV'), ('در', 'ADP'), ('اوردن', 'NOUN,EZ'), ('باتریش', 'NOUN'), ('کمی', 'NOUN,EZ'), ('سخته', 'ADJ')]]
# [[('توی', 'ADP,EZ'), ('شگفت', 'NOUN'), ('انگیز', 'NOUN,EZ'), ('قیمتش', 'NOUN'), ('خوب', 'ADJ'), ('بود', 'VERB')]]
# [[('درکل', 'ADV'), ('شیکهاز', 'NOUN,EZ'), ('عکسشم', 'NOUN,EZ'), ('قشنگ', 'ADJ,EZ'), ('ترهرنگ', 'NOUN,EZ'), ('قرمز', 'ADJ'), ('و', 'CCONJ'), ('زرشکیشم', 'NOUN'), ('فرقی', 'NOUN'), ('باهم', 'ADP'), ('نداره', 'VERB'), ('و', 'CCONJ'), ('هردو', 'NOUN'), ('زرشکی', 'NOUN'), ('هستن', 'VERB')]]
# [[('قیمت', 'NOUN,EZ'), ('بالا', 'ADJ'), ('نسبت', 'NOUN'), ('به', 'ADP'), ('رقبا', 'NOUN')]]
# [[('برای', 'ADP,EZ'), ('کارهای', 'NOUN,EZ'), ('ظریف', 'ADJ'), ('خوبه', 'VERB'), ('ولی', 'CCONJ'), ('سر', 'NOUN,EZ'), ('فک', 'NOUN'), ('انبردست', 'VERB'), ('بهم', 'ADP'), ('نمیچسبه', 'VERB')]]
# [[('من', 'PRON'), ('این', 'DET'), ('محصول', 'NOUN'), ('را', 'ADP'), ('از', 'ADP'), ('دیجی', 'ADJ,EZ'), ('کالا', 'NOUN'), ('گرفتم', 'VERB'), ('و', 'CCONJ'), ('راضیم', 'VERB'), ('ازش', 'ADP')], [('کسانی', 'NOUN'), ('که', 'SCONJ'), ('با', 'ADP'), ('زیر', 'NOUN,EZ'), ('نویس', 'NOUN,EZ'), ('فارسی', 'NOUN'), ('مشکل', 'NOUN'), ('دارند', 'VERB'), ('باید', 'VERB'), ('طبق', 'NOUN,EZ'), ('اموزش', 'NOUN,EZ'), ('من', 'PRON'), ('عمل', 'NOUN'), ('کنند', 'VERB'), ('حالا', 'ADV'), ('چه', 'SCONJ'), ('این', 'DET'), ('محصول', 'NOUN'), ('باشد', 'VERB'), ('و', 'CCONJ'), ('چه', 'SCONJ'), ('سایر', 'NOUN,EZ'), ('محصولات', 'NOUN,EZ'), ('سونی', 'NOUN'), ('سونی', 'NOUN'), ('همانند', 'ADV,EZ'), ('سامسونگ', 'NOUN'), ('و', 'CCONJ'), ('ال', 'NOUN'), ('جی', 'NOUN'), ('از', 'ADP'), ('زبان', 'NOUN,EZ'), ('فارسی', 'NOUN'), ('پشتیبانی', 'NOUN'), ('میکند', 'VERB'), ('1', 'NUM'), ('فایل', 'NOUN'), ('زیر', 'ADP,EZ'), ('نویس', 'NOUN'), ('و', 'CCONJ'), ('فایل', 'NOUN,EZ'), ('فیلم', 'NOUN'), ('را', 'ADP'), ('هم', 'CCONJ'), ('نام', 'NOUN'), ('کنید', 'VERB')], [('2', 'NUM'), ('زیر', 'ADP,EZ'), ('نویس', 'NOUN'), ('را', 'ADP'), ('با', 'ADP'), ('برنامه', 'NOUN,EZ'), ('notepad', 'NOUN'), ('باز', 'ADJ'), ('کنید', 'VERB')], [('3', 'NUM'), ('گزینه', 'NOUN,EZ'), ('File', 'NOUN'), ('را', 'ADP'), ('بزنید', 'VERB')], [('4', 'NUM'), ('گزینه', 'NOUN,EZ'), ('Save', 'NOUN'), ('as', 'NOUN'), ('را', 'ADP'), ('بزنید', 'VERB')], [('5از', 'NOUN,EZ'), ('باکس', 'ADJ,EZ'), ('Encoding', 'NOUN'), ('گزینه', 'NOUN,EZ'), ('UTF8', 'NOUN'), ('را', 'ADP'), ('بزنید', 'VERB')], [('6', 'NUM'), ('گزینه', 'NOUN,EZ'), ('Save', 'NOUN'), ('را', 'ADP'), ('بزنید', 'VERB')], [('7', 'NUM'), ('برروی', 'ADP,EZ'), ('دکمه', 'NOUN,EZ'), ('سبز', 'ADJ'), ('رنگ', 'NOUN,EZ'), ('کنترل', 'NOUN'), ('که', 'SCONJ'), ('مخصوص', 'ADJ,EZ'), ('زیرنویس', 'NOUN'), ('است', 'VERB'), ('کلیک', 'NOUN'), ('کنید', 'VERB'), ('وگزینه', 'NOUN'), ('Font12UTF16', 'NOUN'), ('را', 'ADP'), ('انتخاب', 'NOUN'), ('کنید', 'VERB')]]
# [[('برای', 'ADP,EZ'), ('بستن', 'NOUN,EZ'), ('سیستم', 'NOUN,EZ'), ('highend', 'NOUN'), ('بهتربن', 'NOUN'), ('گزینه', 'NOUN'), ('است', 'VERB'), ('بدلیل', 'ADP,EZ'), ('اینکه', 'CCONJ'), ('بالاترین', 'ADJ'), ('فرکانس', 'NOUN,EZ'), ('ocبین', 'ADJ,EZ'), ('cpuهای', 'NOUN,EZ'), ('اینتل', 'NOUN'), ('را', 'ADP'), ('دارا', 'ADJ'), ('میباشد12مگ', 'NOUN'), ('کشبقولا', 'NOUN'), ('اولین', 'NUM'), ('6هسته', 'NOUN,EZ'), ('ایه', 'NOUN,EZ'), ('12رشته', 'ADJ,EZ'), ('ایه', 'NOUN'), ('اینتله', 'NOUN'), ('ولی', 'CCONJ'), ('همانند', 'ADV,EZ'), ('نسل', 'NOUN,EZ'), ('قبل', 'ADV'), ('های', 'NOUN'), ('لیتو', 'NOUN'), ('گرافی', 'ADJ,EZ'), ('14nmدارد', 'NOUN')], [('بدلیل', 'ADP,EZ'), ('اینکه', 'CCONJ'), ('نسل', 'NOUN'), ('8باید', 'VERB'), ('از', 'ADP'), ('مادر', 'NOUN'), ('برد', 'VERB'), ('های', 'NOUN'), ('z370استفاده', 'NOUN'), ('کنیم', 'VERB'), ('که', 'SCONJ'), ('اینجا', 'ADV'), ('مقرون', 'ADJ'), ('بصرفه', 'VERB'), ('بودن', 'NOUN,EZ'), ('این', 'DET'), ('cpuاز', 'NOUN'), ('بین', 'ADP,EZ'), ('میره130وات', 'NOUN'), ('لازم', 'ADJ'), ('داره', 'VERB')], [('و', 'CCONJ'), ('تفاوتش', 'NOUN'), ('با', 'ADP'), ('8700معمولی', 'NOUN'), ('توی', 'ADP,EZ'), ('فرکانسشه', 'NOUN'), ('و', 'CCONJ'), ('وات', 'NOUN,EZ'), ('مصرفیشاون65', 'NOUN')], [('در', 'ADP'), ('گیمینگ', 'NOUN'), ('بین', 'ADP,EZ'), ('این', 'DET'), ('cpu', 'NOUN'), ('و', 'CCONJ'), ('R5', 'NOUN'), ('1600', 'NUM'), ('تفاوت', 'NOUN,EZ'), ('ناچیزی', 'ADJ'), ('وجود', 'NOUN'), ('داره', 'VERB')], [('مگر', 'ADV'), ('اینکه', 'CCONJ'), ('بخاید', 'VERB'), ('4kبازی', 'NOUN'), ('کنید', 'VERB'), ('که', 'SCONJ'), ('بازم', 'NOUN,EZ'), ('1600خوبهولی', 'NOUN'), ('وقتی', 'SCONJ'), ('جیب', 'NOUN,EZ'), ('شما', 'PRON'), ('میخاد', 'NOUN'), ('حرف', 'NOUN'), ('بزنه', 'VERB'), ('میگه', 'VERB'), ('اون', 'DET'), ('با', 'ADP'), ('نصف', 'NUM,EZ'), ('قیمت', 'NOUN,EZ'), ('بصرفه', 'ADJ,EZ'), ('تره', 'NOUN,EZ'), ('بجاش', 'ADJ'), ('بودجه', 'NOUN,EZ'), ('گرافیک', 'NOUN,EZ'), ('بیشتر', 'ADJ,EZ'), ('میشه', 'NOUN')]]
# [[('وقتی', 'SCONJ'), ('قدر', 'NOUN,EZ'), ('پولت', 'NOUN,EZ'), ('روبدونی', 'ADJ'), ('بهش', 'ADP'), ('ارزش', 'NOUN,EZ'), ('بدی', 'ADJ'), ('انتخاب', 'NOUN,EZ'), ('هاتم', 'NOUN'), ('درست', 'ADJ'), ('میشه', 'VERB')], [('این', 'DET'), ('یکی', 'NUM'), ('از', 'ADP'), ('کالاهایی', 'NOUN'), ('که', 'SCONJ'), ('ارزش', 'NOUN,EZ'), ('هرید', 'NOUN'), ('بالا', 'ADJ'), ('نسبت', 'NOUN'), ('به', 'ADP'), ('قیمتش', 'NOUN'), ('داره', 'VERB'), ('و', 'CCONJ'), ('نیازتونروبرطرف', 'NOUN'), ('میکنه', 'VERB'), ('که', 'SCONJ'), ('هیچحس', 'ADJ,EZ'), ('اینو', 'PRON'), ('بهتون', 'ADP'), ('میده', 'VERB'), ('که', 'SCONJ'), ('سازنده', 'ADJ'), ('برای', 'ADP,EZ'), ('شما', 'PRON'), ('ارزش', 'NOUN,EZ'), ('قائله', 'NOUN')]]
# [[('امروز', 'ADV'), ('به', 'ADP'), ('دستم', 'NOUN'), ('رسید', 'VERB')], [('موقع', 'NOUN,EZ'), ('انداختنش', 'NOUN'), ('که', 'SCONJ'), ('دفعه', 'NOUN'), ('ی', 'NOUN,EZ'), ('اولم', 'NOUN'), ('بود', 'VERB'), ('یکم', 'NUM'), ('سخت', 'ADJ'), ('بود', 'VERB'), ('ولی', 'CCONJ'), ('اخرش', 'NOUN'), ('خوب', 'ADJ'), ('چسبید', 'VERB')], [('تا', 'ADP'), ('حالا', 'ADV'), ('اندازه', 'NOUN,EZ'), ('ی', 'NOUN'), ('نصف', 'NUM,EZ'), ('قیمت', 'NOUN,EZ'), ('گوشی', 'NOUN,EZ'), ('واسه', 'NOUN,EZ'), ('ضدخشا', 'ADJ'), ('هزینه', 'NOUN'), ('کردم', 'VERB'), ('با', 'ADP'), ('قیمتای', 'NOUN,EZ'), ('3برابر', 'NOUN'), ('یا', 'CCONJ'), ('بیشتر', 'ADJ'), ('اما', 'CCONJ'), ('میتونم', 'VERB'), ('بگم', 'VERB'), ('این', 'DET'), ('بهترینننننش', 'NOUN'), ('بود', 'VERB')], [('لبه', 'NOUN,EZ'), ('هاش', 'NOUN'), ('اصلا', 'ADV'), ('بلند', 'ADJ'), ('نشدن', 'NOUN,EZ'), ('این', 'DET'), ('دفعه', 'NOUN'), ('برعکس', 'ADV'), ('همیشه', 'ADV'), ('که', 'SCONJ'), ('بلند', 'ADJ'), ('میشد', 'VERB'), ('و', 'CCONJ'), ('تو', 'PRON'), ('ذوق', 'NOUN'), ('میزد', 'VERB')], [('بازم', 'CCONJ'), ('دو', 'NUM'), ('تا', 'ADP'), ('دیگه', 'PRON'), ('سفارش', 'NOUN'), ('میدم', 'VERB')], [('پیشنهاد', 'NOUN'), ('میکنم', 'VERB'), ('به', 'ADP'), ('همه', 'PRON')]]
# ...
# [[('خیلی', 'ADV'), ('سنگییینه', 'NOUN')]]
# [[('نسبت', 'NOUN'), ('به', 'ADP'), ('قیمتش', 'NOUN'), ('قشنگه', 'VERB')]]
# [[('درمانی', 'ADJ'), ('هست', 'VERB'), ('قوزک', 'NOUN,EZ'), ('پای', 'NOUN,EZ'), ('من', 'PRON'), ('چندلایه', 'ADJ,EZ'), ('پوست', 'NOUN,EZ'), ('خشک', 'ADJ'), ('آورده', 'VERB'), ('بود', 'VERB'), ('به', 'ADP'), ('پیشنهاد', 'NOUN,EZ'), ('دکتر', 'NOUN'), ('پوست', 'NOUN,EZ'), ('یک', 'NUM'), ('ماه', 'NOUN,EZ'), ('هر', 'DET'), ('روز', 'NOUN'), ('از', 'ADP'), ('اوره', 'NOUN,EZ'), ('10', 'NUM'), ('درصدش', 'NOUN'), ('زدم', 'VERB'), ('و', 'CCONJ'), ('کاملا', 'ADV'), ('از', 'ADP'), ('بین', 'NOUN'), ('رفت', 'VERB')], [('واقعا', 'ADV'), ('معجزهآسا', 'ADV'), ('اثر', 'NOUN'), ('کرد', 'VERB')], [('کرمای', 'NOUN,EZ'), ('دیگه', 'PRON'), ('که', 'SCONJ'), ('میزدم', 'VERB'), ('صرفا', 'ADV'), ('چندساعت', 'NOUN,EZ'), ('نرم', 'ADJ'), ('میکرد', 'VERB'), ('و', 'CCONJ'), ('بعد', 'CCONJ'), ('دوباره', 'ADV'), ('همون', 'DET'), ('خشکی', 'NOUN')]]
# [[('بسیار', 'ADV'), ('پر', 'ADJ'), ('کاربرد', 'NOUN'), ('و', 'CCONJ'), ('کارش', 'NOUN'), ('خیلی', 'ADV'), ('خوبه', 'VERB')]]
# [[('دستگاه', 'NOUN,EZ'), ('خوبیه', 'ADJ'), ('یکم', 'NUM'), ('باید', 'VERB'), ('طاقت', 'NOUN'), ('داشته', 'VERB'), ('باشید', 'VERB'), ('و', 'CCONJ'), ('روپوست', 'NOUN'), ('زیاد', 'ADV'), ('فشار', 'NOUN'), ('بیارید', 'VERB'), ('و', 'CCONJ'), ('صد', 'NUM'), ('درصد', 'NOUN'), ('میتونید', 'VERB'), ('جوش', 'NOUN,EZ'), ('سرسیاه', 'ADJ'), ('رو', 'ADP'), ('دربیارید', 'VERB'), ('من', 'PRON'), ('یک', 'NUM'), ('مدل', 'NOUN,EZ'), ('دیگ', 'NOUN'), ('رو', 'ADP'), ('خرید', 'NOUN,EZ'), ('ک', 'NOUN'), ('حلقه', 'NOUN'), ('ای', 'NOUN'), ('بود', 'VERB'), ('نه', 'ADV'), ('مثل', 'ADV,EZ'), ('این', 'PRON')]]
# [[('درب', 'NOUN,EZ'), ('یکیشون', 'PRON'), ('از', 'ADP'), ('ابتدا', 'ADV'), ('خوب', 'ADV'), ('بسته', 'ADJ'), ('نشد', 'VERB'), ('حباب', 'NOUN'), ('داره', 'VERB'), ('جنسش', 'NOUN,EZ'), ('نازکه', 'ADJ'), ('و', 'CCONJ'), ('باید', 'VERB'), ('نراقب', 'NOUN'), ('بود', 'VERB'), ('ضربه', 'NOUN'), ('نخوره', 'VERB')]]
# [[('کیفیت', 'NOUN'), ('به', 'ADP'), ('قیمت', 'NOUN,EZ'), ('نامنلسب', 'NOUN')]]
# [[('سلام', 'NOUN,EZ'), ('دوستان', 'NOUN,EZ'), ('عیدتون', 'NOUN'), ('مبارک', 'ADJ,EZ'), ('من', 'PRON'), ('به', 'ADP'), ('عنوان', 'NOUN,EZ'), ('یه', 'NUM'), ('کسی', 'NOUN'), ('که', 'SCONJ'), ('هر', 'DET'), ('گوشی', 'NOUN'), ('داشتم', 'VERB'), ('و', 'CCONJ'), ('الان', 'ADV'), ('هم', 'CCONJ'), ('سامسونگ', 'NOUN'), ('جی7', 'NOUN'), ('پرو', 'NOUN'), ('دارم', 'VERB'), ('مخوام', 'VERB'), ('بگم', 'VERB'), ('که', 'SCONJ'), ('بیزار', 'ADJ'), ('از', 'ADP'), ('سامسونگ', 'NOUN'), ('و', 'CCONJ'), ('ایفون', 'NOUN,EZ'), ('اینا', 'NOUN'), ('شدمچون', 'NOUN'), ('واقعا', 'ADV'), ('پول', 'NOUN'), ('برند', 'VERB'), ('میدی', 'VERB'), ('تا', 'SCONJ'), ('امکانات', 'NOUN,EZ'), ('خیلیا', 'NOUN'), ('هواوی', 'NOUN'), ('نمی', 'VERB'), ('خرن', 'NOUN'), ('که', 'SCONJ'), ('کیفیت', 'NOUN'), ('نداره', 'VERB'), ('ولی', 'CCONJ'), ('نمیدون', 'VERB'), ('که', 'SCONJ'), ('اقا', 'NOUN'), ('کیفیت', 'NOUN'), ('داره', 'VERB'), ('ولی', 'CCONJ'), ('چون', 'SCONJ'), ('پول', 'NOUN'), ('برند', 'VERB'), ('نمیدی', 'VERB'), ('قیمتش', 'NOUN'), ('پایین', 'ADV'), ('تر', 'ADJ'), ('هزار', 'NUM'), ('چیز', 'NOUN'), ('میگین', 'VERB'), ('والا', 'SCONJ'), ('من', 'PRON'), ('ایفون', 'NOUN,EZ'), ('7', 'NOUN'), ('داشتم', 'VERB'), ('دادم', 'VERB'), ('اینو', 'NOUN'), ('می', 'NOUN'), ('خوام', 'VERB'), ('بخرم', 'VERB'), ('چون', 'SCONJ'), ('واقعا', 'ADV'), ('گوشیش', 'NOUN,EZ'), ('عالیه', 'ADJ'), ('و', 'CCONJ'), ('نسبت', 'NOUN'), ('به', 'ADP'), ('قیمتش', 'NOUN'), ('می', 'NOUN,EZ'), ('ارزه', 'NOUN,EZ'), ('من', 'PRON'), ('ایفون', 'NOUN,EZ'), ('7', 'NUM,EZ'), ('رو', 'NOUN'), ('با', 'ADP'), ('این', 'DET'), ('گوشی', 'NOUN,EZ'), ('تست', 'NOUN,EZ'), ('کردمهم', 'ADJ,EZ'), ('دوربین', 'NOUN'), ('و', 'CCONJ'), ('هم', 'CCONJ'), ('سرعت', 'NOUN'), ('و', 'CCONJ'), ('باتری', 'NOUN,EZ'), ('تو', 'PRON'), ('سرعت', 'NOUN'), ('مثل', 'ADV,EZ'), ('همن', 'NOUN'), ('ولی', 'CCONJ'), ('دوربین', 'NOUN,EZ'), ('پی10', 'NOUN'), ('لایت', 'NOUN'), ('قوی', 'ADJ'), ('تر', 'ADJ'), ('بود', 'VERB'), ('همینطور', 'DET'), ('باطریشفقط', 'NOUN,EZ'), ('پول', 'NOUN'), ('الکی', 'ADV'), ('دادم', 'VERB'), ('برا', 'ADP'), ('ایفون', 'NOUN,EZ'), ('دلخوشیم', 'NOUN'), ('کلاس', 'NOUN'), ('داره', 'VERB'), ('برنده', 'NOUN')]]
# [[('وصل', 'NOUN'), ('کردنش', 'NOUN'), ('از', 'ADP'), ('اب', 'NOUN'), ('خوردن', 'NOUN,EZ'), ('راخت', 'NOUN'), ('تره', 'NOUN')], [('فقط', 'ADV'), ('کافیه', 'NOUN'), ('به', 'ADP'), ('مودم', 'NOUN'), ('وصلش', 'NOUN'), ('کنید', 'VERB'), ('و', 'CCONJ'), ('نرم', 'ADJ,EZ'), ('افزارش', 'NOUN'), ('واسه', 'ADP'), ('گوشی', 'NOUN'), ('بگیرید', 'VERB')], [('نصبش', 'NOUN'), ('15', 'NUM'), ('دقیقه', 'NOUN,EZ'), ('زمان', 'NOUN,EZ'), ('میبره', 'NOUN'), ('فقط', 'ADV')], [('صدا', 'NOUN'), ('ضبط', 'NOUN'), ('نمیکنه', 'VERB'), ('زوم', 'NOUN'), ('اپتیکال', 'NOUN'), ('نداره', 'VERB'), ('ولی', 'CCONJ'), ('کیفیت', 'NOUN,EZ'), ('فیلمی', 'NOUN'), ('که', 'SCONJ'), ('میده', 'VERB'), ('قابل', 'ADJ,EZ'), ('قبوله', 'NOUN'), ('و', 'CCONJ'), ('دید', 'NOUN'), ('در', 'ADP'), ('شب', 'NOUN,EZ'), ('خوبی', 'ADJ'), ('داره', 'VERB')], [('من', 'PRON'), ('تو', 'PRON'), ('تخفیف', 'NOUN,EZ'), ('دیجیکالا', 'ADJ'), ('خریدم', 'VERB'), ('و', 'CCONJ'), ('از', 'ADP'), ('خریدم', 'NOUN'), ('راضیم', 'VERB')], [('به', 'ADP'), ('نظرم', 'NOUN'), ('کیفیت', 'NOUN,EZ'), ('ساختش', 'NOUN'), ('اوکیه', 'VERB'), ('ولی', 'CCONJ'), ('عالی', 'ADJ'), ('نیست', 'VERB')]]
# [[('خرید', 'NOUN'), ('کردم', 'VERB'), ('بسیار', 'ADV'), ('عالیه', 'ADJ'), ('به', 'ADP'), ('همه', 'DET,EZ'), ('پیشنهاد', 'NOUN'), ('میکنم', 'VERB'), ('خرید', 'NOUN,EZ'), ('کنن', 'NOUN'), ('بسیار', 'ADV'), ('خوش', 'ADJ'), ('دست', 'NOUN'), ('و', 'CCONJ'), ('به', 'ADP'), ('روز', 'NOUN'), ('اندروید', 'VERB'), ('8', 'NUM'), ('دو', 'NUM'), ('دوربین', 'NOUN'), ('پشت', 'ADP,EZ'), ('بسیار', 'DET'), ('حرفه', 'NOUN'), ('ای', 'INTJ'), ('دوربین', 'NOUN,EZ'), ('سلفی', 'ADJ,EZ'), ('عالی', 'ADJ,EZ'), ('امکانات', 'NOUN,EZ'), ('دوربین', 'NOUN,EZ'), ('پشتش', 'NOUN'), ('عالی', 'ADJ'), ('و', 'CCONJ'), ('حرفه', 'NOUN,EZ'), ('ایه', 'NOUN'), ('اصلا', 'ADV'), ('در', 'ADP'), ('کل', 'NOUN'), ('با', 'ADP'), ('توجه', 'NOUN'), ('به', 'ADP'), ('قیمت', 'NOUN'), ('و', 'CCONJ'), ('امکانات', 'NOUN,EZ'), ('بسیار', 'ADV'), ('میارزه', 'NOUN')]]
# [[('اصلا', 'ADV'), ('هیچ', 'DET'), ('اثری', 'NOUN'), ('نداره', 'VERB')]]
# [[('دقت', 'NOUN'), ('کنید', 'VERB'), ('که', 'SCONJ'), ('این', 'DET'), ('دستگاه', 'NOUN'), ('روتر', 'NOUN'), ('هست', 'VERB'), ('و', 'CCONJ'), ('از', 'ADP'), ('خودش', 'PRON'), ('اینترنتی', 'NOUN'), ('نداره', 'VERB')], [('صرفا', 'ADV'), ('اگر', 'SCONJ'), ('به', 'ADP'), ('دنبال', 'NOUN,EZ'), ('ارتقای', 'NOUN,EZ'), ('شبکه', 'NOUN,EZ'), ('منزل', 'NOUN'), ('به', 'ADP'), ('استاندارد', 'NOUN,EZ'), ('AC', 'NOUN'), ('هستید', 'VERB'), ('میتونید', 'VERB'), ('از', 'ADP'), ('این', 'DET'), ('مدل', 'NOUN'), ('استفاده', 'NOUN'), ('کنید', 'VERB')], [('وگرنه', 'SCONJ'), ('اگر', 'SCONJ'), ('منبع', 'NOUN,EZ'), ('اینترنت', 'NOUN,EZ'), ('مناسبی', 'ADJ'), ('نداشته', 'VERB'), ('باشید', 'VERB'), ('برای', 'ADP,EZ'), ('کانفیگ', 'NOUN'), ('اون', 'PRON'), ('به', 'ADP'), ('مشکل', 'NOUN'), ('برمیخورید', 'VERB')], [('همچنین', 'CCONJ'), ('به', 'ADP'), ('همراه', 'NOUN,EZ'), ('این', 'DET'), ('محصول', 'NOUN,EZ'), ('کابل', 'NOUN,EZ'), ('PATCH', 'NOUN'), ('ارائه', 'NOUN'), ('نمیشه', 'VERB'), ('پس', 'SCONJ'), ('برای', 'ADP,EZ'), ('اتصال', 'NOUN,EZ'), ('اینترنت', 'NOUN'), ('به', 'ADP'), ('پورت', 'NOUN,EZ'), ('WAN', 'NOUN'), ('روی', 'ADP,EZ'), ('این', 'DET'), ('روتر', 'NOUN'), ('باید', 'VERB'), ('یه', 'NUM'), ('کابل', 'NOUN'), ('PATCH', 'NOUN'), ('حداقل', 'ADV'), ('نیم', 'NUM'), ('متری', 'NOUN'), ('خریداری', 'NOUN'), ('کنید', 'VERB')], [('همچنین', 'CCONJ'), ('پورت', 'NOUN,EZ'), ('USB', 'NOUN'), ('فقط', 'ADV'), ('برای', 'ADP,EZ'), ('اتصال', 'NOUN,EZ'), ('دستگاه', 'NOUN,EZ'), ('های', 'NOUN'), ('ذخیره', 'NOUN,EZ'), ('سازی', 'NOUN,EZ'), ('اطلاعات', 'NOUN'), ('مثل', 'ADV,EZ'), ('هارد', 'NOUN'), ('اکسترنال', 'NOUN'), ('هست', 'VERB')], [('و', 'CCONJ'), ('توی', 'ADP,EZ'), ('پنل', 'NOUN'), ('روتر', 'NOUN'), ('قابلیت', 'NOUN,EZ'), ('مدیریت', 'NOUN,EZ'), ('دانلود', 'ADJ'), ('هم', 'CCONJ'), ('داره', 'VERB')], [('صد', 'NUM'), ('افسوس', 'NOUN'), ('که', 'SCONJ'), ('این', 'DET'), ('پورت', 'NOUN'), ('رو', 'ADP'), ('نمیشه', 'VERB'), ('برای', 'ADP,EZ'), ('دانگل', 'NOUN'), ('های', 'NOUN'), ('3G4G', 'NOUN'), ('استفاده', 'NOUN')], [('درضمن', 'CCONJ'), ('اگر', 'SCONJ'), ('به', 'ADP'), ('دنبال', 'NOUN,EZ'), ('شخصی', 'NOUN'), ('سازی', 'NOUN'), ('این', 'DET'), ('روتر', 'NOUN'), ('با', 'ADP'), ('OpenWrt', 'NOUN'), ('هستید', 'VERB'), ('باید', 'VERB'), ('خدمتتون', 'NOUN'), ('عرض', 'NOUN'), ('کنم', 'VERB'), ('حافظه', 'NOUN,EZ'), ('این', 'DET'), ('روتر', 'NOUN'), ('بعد', 'ADP'), ('از', 'ADP'), ('کانفیگ', 'NOUN,EZ'), ('اولیه', 'ADJ'), ('به', 'ADP'), ('حالت', 'NOUN'), ('فقط', 'ADV'), ('خواندنی', 'ADJ'), ('تبدیل', 'NOUN,EZ'), ('میشه', 'NOUN')], [('البته', 'ADV'), ('اگر', 'SCONJ'), ('خیلی', 'ADV'), ('سمج', 'ADJ'), ('باشین', 'VERB'), ('میشه', 'NOUN'), ('تغییرش', 'NOUN'), ('داد', 'VERB'), ('ولی', 'CCONJ'), ('اگه', 'SCONJ'), ('اشتباه', 'NOUN,EZ'), ('کوچیکی', 'ADJ'), ('ازتون', 'ADP'), ('سر', 'NOUN'), ('بزنه', 'VERB'), ('همه', 'DET'), ('چیز', 'NOUN'), ('خراب', 'ADJ'), ('میشه', 'VERB'), ('و', 'CCONJ'), ('دستگاه', 'NOUN,EZ'), ('میمونه', 'ADJ'), ('روی', 'ADP,EZ'), ('دستتون', 'NOUN')], [('درمورد', 'ADP,EZ'), ('بدنه', 'NOUN,EZ'), ('این', 'DET'), ('دستگاه', 'NOUN')], [('خیلی', 'ADV'), ('ضعیف', 'ADJ'), ('و', 'CCONJ'), ('شکننده', 'ADJ'), ('به', 'ADP'), ('نظر', 'NOUN,EZ'), ('میرسه', 'NOUN'), ('اما', 'CCONJ'), ('خب', 'ADV'), ('این', 'PRON'), ('یه', 'NUM'), ('روتره', 'NOUN'), ('قندون', 'NOUN'), ('نیست', 'VERB'), ('که', 'SCONJ'), ('جلوی', 'ADP,EZ'), ('دست', 'NOUN,EZ'), ('مهمون', 'ADJ'), ('باشه', 'VERB')], [('طبیعتا', 'ADV'), ('بعد', 'CCONJ'), ('کانفیگ', 'NOUN'), ('روی', 'ADP,EZ'), ('یه', 'NUM'), ('میز', 'NOUN'), ('یا', 'CCONJ'), ('جای', 'NOUN,EZ'), ('بلند', 'ADJ'), ('قرار', 'NOUN,EZ'), ('میگیره', 'NOUN,EZ'), ('دور', 'ADJ'), ('از', 'ADP'), ('دسترس', 'NOUN,EZ'), ('بچه', 'NOUN,EZ'), ('ها', 'NOUN')], [('برای', 'ADP,EZ'), ('پاور', 'NOUN'), ('هم', 'CCONJ'), ('باید', 'VERB'), ('یه', 'NUM'), ('تبدیل', 'NOUN'), ('بگیرید', 'VERB'), ('چون', 'SCONJ'), ('پاور', 'NOUN'), ('خودش', 'PRON'), ('با', 'ADP'), ('پریز', 'NOUN,EZ'), ('ایران', 'NOUN'), ('سازگار', 'ADJ'), ('نیست', 'VERB')], [('دفترچه', 'NOUN'), ('هم', 'CCONJ'), ('چینیه', 'NOUN' ...
# [[('خوبه', 'VERB'), ('البته', 'ADV'), ('نسبت', 'NOUN'), ('به', 'ADP'), ('کاراییش', 'NOUN'), ('قیمتشم', 'NOUN'), ('خوبه', 'VERB')]]
# [[('من', 'PRON'), ('این', 'DET'), ('سرویس', 'NOUN'), ('قابلمه', 'NOUN'), ('رو', 'ADP'), ('تو', 'PRON'), ('شگفت', 'VERB'), ('انگیز', 'ADJ'), ('خریدم', 'VERB'), ('از', 'ADP'), ('این', 'DET'), ('ارزونتر', 'NOUN'), ('بودجنس', 'NOUN'), ('قابلمه', 'NOUN,EZ'), ('خوب', 'ADJ'), ('هست', 'VERB'), ('با', 'ADP'), ('توجه', 'NOUN'), ('به', 'ADP'), ('قیمتش', 'NOUN'), ('اما', 'CCONJ'), ('بهتر', 'ADJ'), ('بود', 'VERB'), ('جنس', 'NOUN,EZ'), ('دسته', 'NOUN'), ('ها', 'NOUN'), ('کیفیت', 'NOUN,EZ'), ('بهتری', 'ADJ'), ('داشته', 'VERB'), ('باشه', 'VERB'), ('سایز', 'NOUN,EZ'), ('قابلمه', 'ADJ,EZ'), ('بزرگ', 'ADJ'), ('برای', 'ADP,EZ'), ('خانواده', 'NOUN,EZ'), ('های', 'NOUN'), ('پرجمعیت', 'ADJ'), ('خوبه', 'VERB'), ('اما', 'CCONJ'), ('دو', 'NUM'), ('تای', 'NOUN,EZ'), ('دیگه', 'PRON'), ('مناسب', 'ADJ'), ('هست', 'VERB'), ('برای', 'ADP,EZ'), ('چهار', 'NUM'), ('نفر', 'NOUN'), ('در', 'ADP'), ('کل', 'NOUN'), ('از', 'ADP'), ('خریدم', 'NOUN,EZ'), ('پشیمون', 'ADJ'), ('نیستم', 'VERB')]]
# [[('پوشش', 'NOUN'), ('دهی', 'NOUN'), ('صفراصلا', 'ADV'), ('پیشنهاد', 'NOUN'), ('نمیکنم', 'VERB')]]
# [[('نصب', 'NOUN,EZ'), ('این', 'DET'), ('فن', 'NOUN'), ('خیلی', 'ADV'), ('راحته', 'VERB'), ('و', 'CCONJ'), ('دردسر', 'NOUN,EZ'), ('زیادی', 'ADJ'), ('نداره', 'VERB'), ('درضمن', 'CCONJ'), ('به', 'ADP'), ('همراه', 'NOUN,EZ'), ('محصول', 'NOUN,EZ'), ('خمیر', 'NOUN,EZ'), ('سیلیکون', 'NOUN'), ('هم', 'CCONJ'), ('هست', 'VERB'), ('نیازی', 'NOUN'), ('به', 'ADP'), ('خرید', 'NOUN'), ('ندارید', 'VERB')], [('درمورد', 'ADP,EZ'), ('بازی', 'NOUN,EZ'), ('های', 'NOUN'), ('سنگین', 'ADJ'), ('ببینید', 'VERB'), ('اگر', 'SCONJ'), ('SETUP', 'NOUN'), ('شما', 'PRON'), ('برای', 'ADP,EZ'), ('گیمینگ', 'NOUN'), ('باشه', 'VERB'), ('طبیعتا', 'ADV'), ('کیس', 'NOUN'), ('هم', 'CCONJ'), ('یک', 'NUM'), ('دمای', 'NOUN,EZ'), ('خنک', 'ADJ'), ('و', 'CCONJ'), ('متعادلی', 'ADJ'), ('داره', 'VERB')], [('و', 'CCONJ'), ('این', 'DET'), ('فن', 'NOUN'), ('توی', 'ADP,EZ'), ('اون', 'DET'), ('شرایط', 'NOUN'), ('میتونه', 'VERB'), ('درحد', 'ADJ'), ('یک', 'NUM'), ('خنک', 'NOUN'), ('کننده', 'NOUN,EZ'), ('آبی', 'ADJ'), ('کارایی', 'NOUN'), ('داشته', 'VERB'), ('باشه', 'VERB')], [('اما', 'CCONJ'), ('اگر', 'SCONJ'), ('کیس', 'NOUN'), ('شما', 'PRON'), ('یه', 'NUM'), ('مدل', 'NOUN,EZ'), ('معمولی', 'ADJ'), ('با', 'ADP'), ('سه', 'NUM'), ('تا', 'ADP'), ('فن', 'NOUN,EZ'), ('سادست', 'ADJ'), ('خیلی', 'ADV'), ('درحد', 'ADV'), ('بازی', 'NOUN'), ('ازش', 'ADP'), ('انتظار', 'NOUN'), ('نداشته', 'VERB'), ('باشید', 'VERB')], [('میتونه', 'NOUN'), ('تا', 'ADP'), ('10', 'NUM'), ('الی', 'ADP'), ('15', 'NUM'), ('درجه', 'NOUN'), ('دما', 'NOUN'), ('رو', 'ADP'), ('خنک', 'ADJ'), ('کنه', 'VERB')]]
# [[('بی', 'ADP'), ('کیفیت', 'NOUN')]]
# [[('سلام', 'NOUN,EZ'), ('چندماهی', 'ADJ'), ('میشه', 'VERB'), ('این', 'DET'), ('پاور', 'NOUN'), ('بانک', 'NOUN'), ('رو', 'ADP'), ('تهیه', 'NOUN'), ('کردم', 'VERB'), ('طبق', 'NOUN,EZ'), ('تستی', 'NOUN'), ('که', 'SCONJ'), ('انجام', 'NOUN'), ('دادم', 'VERB'), ('2', 'NUM'), ('بار', 'NOUN'), ('گوشی', 'NOUN,EZ'), ('3200', 'NUM'), ('میلی', 'NOUN'), ('آمپری', 'NOUN'), ('رو', 'ADP'), ('شارژ', 'NOUN'), ('میکنه', 'VERB'), ('که', 'SCONJ'), ('جمعا', 'ADV'), ('6400', 'NUM'), ('میلی', 'NOUN'), ('آمپر', 'NOUN'), ('اینکه', 'CCONJ'), ('گفتن', 'NOUN,EZ'), ('12500', 'NUM,EZ'), ('ادعایی', 'NOUN'), ('بیش', 'ADJ'), ('نیست', 'VERB'), ('خیلی', 'ADV'), ('طول', 'NOUN,EZ'), ('میکشه', 'ADJ,EZ'), ('خودش', 'PRON'), ('شارژ', 'NOUN'), ('شه', 'NOUN,EZ'), ('زودم', 'ADJ'), ('خالی', 'ADJ'), ('میشه', 'VERB'), ('عدد', 'NOUN,EZ'), ('100', 'NUM,EZ'), ('رو', 'NOUN'), ('هم', 'CCONJ'), ('نمیتونه', 'VERB'), ('نشون', 'NOUN'), ('بده', 'VERB'), ('چون', 'SCONJ'), ('LED', 'NOUN'), ('که', 'SCONJ'), ('داره', 'VERB'), ('2', 'NUM'), ('رقمیه', 'NOUN'), ('پس', 'ADP'), ('انتهاش', 'NOUN'), ('99', 'NOUN'), ('هست', 'VERB'), ('وزنش', 'NOUN'), ('هم', 'CCONJ'), ('زیاده', 'VERB')]]
# [[('این', 'DET'), ('مدل', 'NOUN'), ('رو', 'ADP'), ('من', 'PRON'), ('چند', 'DET'), ('روزی', 'NOUN'), ('هست', 'VERB'), ('که', 'SCONJ'), ('دریافت', 'NOUN,EZ'), ('کردمتوی', 'NOUN,EZ'), ('این', 'DET'), ('چندروز', 'NOUN'), ('مشکلی', 'NOUN'), ('نداشته', 'VERB'), ('و', 'CCONJ'), ('واسم', 'NOUN,EZ'), ('خوب', 'ADJ'), ('و', 'CCONJ'), ('خوش', 'ADJ,EZ'), ('یمن', 'NOUN'), ('بودهگوشی', 'NOUN'), ('گلکسی', 'NOUN'), ('جی', 'NOUN'), ('سون', 'NOUN'), ('پریم', 'VERB'), ('منو', 'PRON'), ('8', 'NUM'), ('بار', 'NOUN'), ('بطور', 'ADP,EZ'), ('کامل', 'ADJ,EZ'), ('شارژ', 'NOUN,EZ'), ('میکنه', 'NOUN')]]

# %% [markdown]
# # **Occurence of tags**

# %%
tag_counts = {}

for sentence_tags in tagged_dataset:
    for word_tag_pair in sentence_tags:
        if len(word_tag_pair) > 1:
            tag = word_tag_pair[1]
            if tag in tag_counts:
                tag_counts[tag] += 1
            else:
                tag_counts[tag] = 1

for tag, count in tag_counts.items():
    print(f"Tag: {tag}, Count: {count}")
# Out:
# Tag: ('به', 'ADP'), Count: 15
# Tag: ('ماهی', 'NOUN'), Count: 1
# Tag: ('برنامه', 'NOUN,EZ'), Count: 3
# Tag: ('از', 'ADP'), Count: 13
# Tag: ('ستون', 'NOUN,EZ'), Count: 1
# Tag: ('همه', 'DET,EZ'), Count: 1
# Tag: ('نکته', 'NOUN,EZ'), Count: 1
# Tag: ('در', 'ADP'), Count: 2
# Tag: ('هو', 'NOUN'), Count: 1
# Tag: ('سبک', 'ADJ'), Count: 1
# Tag: ('خیلی', 'ADV'), Count: 10
# Tag: ('خوبه', 'VERB'), Count: 4
# Tag: ('پیشنهاد', 'NOUN'), Count: 8
# Tag: ('چند', 'DET'), Count: 3
# Tag: ('کارکرد', 'NOUN,EZ'), Count: 1
# Tag: ('های', 'NOUN'), Count: 4
# Tag: ('و', 'CCONJ'), Count: 8
# Tag: ('خوب', 'ADJ,EZ'), Count: 1
# Tag: ('ساخت', 'NOUN,EZ'), Count: 1
# Tag: ('کل', 'NOUN,EZ'), Count: 3
# Tag: ('گردن', 'NOUN'), Count: 1
# Tag: ('عالی', 'ADJ'), Count: 2
# Tag: ('کفش', 'NOUN,EZ'), Count: 2
# Tag: ('عنوان', 'NOUN,EZ'), Count: 1
# Tag: ('من', 'PRON'), Count: 9
# Tag: ('واقعا', 'ADV'), Count: 1
# Tag: ('بهش', 'ADP'), Count: 1
# Tag: ('تا', 'NOUN'), Count: 1
# Tag: ('با', 'ADP'), Count: 4
# Tag: ('بر', 'NOUN'), Count: 1
# Tag: ('پیشنهاد', 'NOUN,EZ'), Count: 2
# Tag: ('عالیه', 'ADJ'), Count: 5
# Tag: ('الان', 'ADV'), Count: 2
# Tag: ('ویژه', 'ADJ,EZ'), Count: 1
# Tag: ('لپ', 'NOUN'), Count: 1
# Tag: ('قابل', 'ADJ,EZ'), Count: 1
# Tag: ('فقط', 'ADV'), Count: 1
# Tag: ('نظر', 'NOUN'), Count: 2
# Tag: ('العادس', 'NOUN'), Count: 1
# Tag: ('صداش', 'NOUN'), Count: 1
# Tag: ('گلس', 'NOUN'), Count: 1
# Tag: ('ساعت', 'NOUN'), Count: 3
# Tag: ('کمم', 'NOUN'), Count: 1
# Tag: ('نظر', 'NOUN,EZ'), Count: 2
# Tag: ('خرید', 'NOUN'), Count: 1
# Tag: ('سفارش', 'NOUN'), Count: 2
# Tag: ('زودتر', 'ADV'), Count: 1
# Tag: ('انتظار', 'NOUN'), Count: 1
# Tag: ('بودم', 'VERB'), Count: 1
# Tag: ('میکنه', 'VERB'), Count: 1
# Tag: ('میکنم', 'VERB'), Count: 4
# Tag: ('رو', 'ADP'), Count: 1
# Tag: ('ابن', 'NOUN,EZ'), Count: 1
# Tag: ('هر', 'DET'), Count: 2
# Tag: ('خودنویس', 'NOUN'), Count: 1
# Tag: ('لوازم', 'NOUN,EZ'), Count: 1
# Tag: ('دیجیکالا', 'ADV'), Count: 1
# Tag: ('رم', 'NOUN'), Count: 1
# Tag: ('هفته', 'NOUN'), Count: 2
# Tag: ('دارم', 'VERB'), Count: 1
# Tag: ('محصول', 'NOUN'), Count: 1
# Tag: ('اندازی', 'NOUN'), Count: 1
# Tag: ('خوبیه', 'VERB'), Count: 3
# Tag: ('بلوتوث', 'NOUN'), Count: 1
# Tag: ('ساله', 'NOUN'), Count: 1
# Tag: ('قدرت', 'NOUN,EZ'), Count: 1
# Tag: ('دو', 'NUM'), Count: 3
# Tag: ('بعد', 'NOUN,EZ'), Count: 1
# Tag: ('کسانیکه', 'NOUN'), Count: 1
# Tag: ('این', 'DET'), Count: 19
# Tag: ('مشکیدرکل', 'NOUN'), Count: 1
# Tag: ('صدای', 'NOUN,EZ'), Count: 1
# Tag: ('نظرم', 'NOUN'), Count: 3
# Tag: ('کل', 'NOUN'), Count: 4
# Tag: ('خوب', 'ADJ'), Count: 2
# Tag: ('تو', 'PRON'), Count: 2
# Tag: ('یخورده', 'ADJ,EZ'), Count: 1
# Tag: ('کانال', 'NOUN'), Count: 1
# Tag: ('کنده', 'VERB'), Count: 1
# Tag: ('ایکس', 'NOUN'), Count: 1
# Tag: ('چرا', 'ADV'), Count: 1
# Tag: ('یو', 'NOUN'), Count: 1
# Tag: ('هم', 'CCONJ'), Count: 6
# Tag: ('55', 'NUM'), Count: 1
# Tag: ('باطریش', 'NOUN'), Count: 1
# Tag: ('اینترنت', 'NOUN'), Count: 1
# Tag: ('صفحه', 'NOUN,EZ'), Count: 2
# Tag: ('باز', 'ADV'), Count: 1
# Tag: ('واسه', 'ADP'), Count: 1
# Tag: ('قسمت', 'NOUN,EZ'), Count: 1
# Tag: ('اگه', 'SCONJ'), Count: 2
# Tag: ('اون', 'DET'), Count: 1
# Tag: ('خوبی', 'ADJ'), Count: 2
# Tag: ('سردرد', 'NOUN'), Count: 1
# Tag: ('برای', 'ADP,EZ'), Count: 2
# Tag: ('خوش', 'ADJ'), Count: 1
# Tag: ('بدنش', 'NOUN'), Count: 1
# Tag: ('شگفت', 'NOUN'), Count: 1
# Tag: ('شیکهاز', 'NOUN,EZ'), Count: 1
# Tag: ('بالا', 'ADJ'), Count: 2
# Tag: ('کارهای', 'NOUN,EZ'), Count: 1
# Tag: ('که', 'SCONJ'), Count: 4
# Tag: ('زیر', 'ADP,EZ'), Count: 1
# Tag: ('گزینه', 'NOUN,EZ'), Count: 3
# Tag: ('باکس', 'ADJ,EZ'), Count: 1
# Tag: ('برروی', 'ADP,EZ'), Count: 1
# Tag: ('بستن', 'NOUN,EZ'), Count: 1
# Tag: ('اینکه', 'CCONJ'), Count: 4
# Tag: ('تفاوتش', 'NOUN'), Count: 1
# Tag: ('گیمینگ', 'NOUN'), Count: 1
# Tag: ('قدر', 'NOUN,EZ'), Count: 1
# Tag: ('یکی', 'NUM'), Count: 2
# Tag: ('انداختنش', 'NOUN'), Count: 1
# Tag: ('حالا', 'ADV'), Count: 1
# Tag: ('هاش', 'NOUN'), Count: 1
# Tag: ('روزه', 'NOUN'), Count: 1
# Tag: ('بندیش', 'ADJ'), Count: 1
# Tag: ('خود', 'PRON,EZ'), Count: 1
# Tag: ('ریموت', 'NOUN'), Count: 1
# Tag: ('ضعف', 'NOUN,EZ'), Count: 1
# Tag: ('ولی', 'CCONJ'), Count: 2
# Tag: ('مشخصاتش', 'NOUN'), Count: 1
# Tag: ('اول', 'ADV'), Count: 1
# Tag: ('پولشو', 'ADP'), Count: 1
# Tag: ('لازمم', 'ADJ'), Count: 1
# Tag: ('مهره', 'NOUN,EZ'), Count: 1
# Tag: ('خانم', 'NOUN,EZ'), Count: 1
# Tag: ('5', 'NUM'), Count: 2
# Tag: ('سری', 'NOUN'), Count: 1
# Tag: ('مثل', 'ADV,EZ'), Count: 1
# Tag: ('دوربین', 'NOUN'), Count: 1
# Tag: ('امکانات', 'NOUN,EZ'), Count: 1
# Tag: ('درد', 'NOUN,EZ'), Count: 1
# Tag: ('یه', 'NUM'), Count: 2
# Tag: ('بگم', 'VERB'), Count: 1
# Tag: ('بود', 'VERB'), Count: 2
# Tag: ('بد', 'ADJ'), Count: 1
# Tag: ('تاحالا', 'ADV'), Count: 1
# Tag: ('گوشی', 'NOUN,EZ'), Count: 2
# Tag: ('مشکیه', 'NOUN'), Count: 1
# Tag: ('نمیدونم', 'VERB'), Count: 1
# Tag: ('زود', 'ADV'), Count: 1
# Tag: ('مشابه', 'ADJ,EZ'), Count: 1
# Tag: ('محصولات', 'NOUN,EZ'), Count: 1
# Tag: ('نداره', 'VERB'), Count: 2
# Tag: ('بدون', 'ADP,EZ'), Count: 1
# Tag: ('دنبال', 'NOUN,EZ'), Count: 1
# Tag: ('خریدیمچینی', 'NOUN,EZ'), Count: 1
# Tag: ('زیبایی', 'ADJ'), Count: 1
# Tag: ('دوسش', 'NOUN'), Count: 1
# Tag: ('چیزی', 'NOUN'), Count: 1
# Tag: ('یکم', 'NUM'), Count: 2
# Tag: ('متاسفانه', 'ADV'), Count: 1
# Tag: ('تحویل', 'NOUN'), Count: 1
# Tag: ('هفته', 'NOUN,EZ'), Count: 1
# Tag: ('فیلتری', 'NOUN'), Count: 1
# Tag: ('مثلا', 'ADV'), Count: 1
# Tag: ('خب', 'ADV'), Count: 1
# Tag: ('نظراتی', 'NOUN'), Count: 1
# Tag: ('نظافت', 'NOUN'), Count: 1
# Tag: ('لولا', 'NOUN'), Count: 1
# Tag: ('تجربه', 'NOUN'), Count: 1
# Tag: ('لذت', 'NOUN,EZ'), Count: 1
# Tag: ('قهوه', 'NOUN,EZ'), Count: 1
# Tag: ('کتاب', 'NOUN,EZ'), Count: 1
# Tag: ('کلا', 'ADV'), Count: 1
# Tag: ('فوق', 'ADJ'), Count: 2
# Tag: ('باورنکردنیه', 'NOUN'), Count: 1
# Tag: ('همچین', 'ADV'), Count: 1
# Tag: ('بدونین', 'CCONJ'), Count: 1
# Tag: ('افرادی', 'NOUN'), Count: 1
# Tag: ('کالا', 'NOUN'), Count: 1
# Tag: ('داخلش', 'NOUN'), Count: 1
# Tag: ('هنگ', 'NOUN'), Count: 1
# Tag: ('زیبایی', 'NOUN'), Count: 1
# Tag: ('فارسیش', 'ADJ'), Count: 1
# Tag: ('البته', 'ADV'), Count: 3
# Tag: ('جوره', 'NOUN,EZ'), Count: 1
# Tag: ('نو', 'ADJ'), Count: 1
# Tag: ('دوم', 'ADJ,EZ'), Count: 1
# Tag: ('روز', 'NOUN,EZ'), Count: 1
# Tag: ('پس', 'ADP'), Count: 1
# Tag: ('اجبارا', 'ADV'), Count: 1
# Tag: ('را', 'ADP'), Count: 1
# Tag: ('ایحال', 'NOUN'), Count: 1
# Tag: ('لحاظ', 'NOUN,EZ'), Count: 1
# Tag: ('کنندس', 'NOUN'), Count: 1
# Tag: ('یک', 'NUM'), Count: 3
# Tag: ('کاش', 'ADV'), Count: 1
# Tag: ('بخرید', 'VERB'), Count: 1
# Tag: ('پر', 'ADJ'), Count: 2
# Tag: ('بندی', 'NOUN'), Count: 1
# Tag: ('سامسونگ', 'NOUN'), Count: 1
# Tag: ('حدود', 'DET,EZ'), Count: 1
# Tag: ('روزمره', 'ADJ,EZ'), Count: 1
# Tag: ('هدیه', 'NOUN,EZ'), Count: 2
# Tag: ('بسیار', 'ADV'), Count: 1
# Tag: ('بهترین', 'ADJ'), Count: 1
# Tag: ('نسبت', 'NOUN'), Count: 2
# Tag: ('عکس', 'NOUN,EZ'), Count: 1
# Tag: ('حد', 'NOUN,EZ'), Count: 1
# Tag: ('دورببن', 'NOUN'), Count: 1
# Tag: ('صفحه', 'NOUN'), Count: 2
# Tag: ('خام', 'ADJ'), Count: 1
# Tag: ('سلام', 'NOUN'), Count: 2
# Tag: ('جنس', 'NOUN,EZ'), Count: 1
# Tag: ('عملکرده', 'ADV'), Count: 1
# Tag: ('مناسب', 'ADJ'), Count: 1
# Tag: ('بین', 'ADP,EZ'), Count: 1
# Tag: ('پرفیوم', 'NOUN'), Count: 1
# Tag: ('حمایت', 'NOUN'), Count: 1
# Tag: ('خوب', 'ADV'), Count: 1
# Tag: ('کفپوش', 'NOUN'), Count: 1
# Tag: ('تازه', 'ADV'), Count: 1
# Tag: ('روز', 'NOUN'), Count: 1
# Tag: ('یعنی', 'CCONJ'), Count: 1
# Tag: ('خریدم', 'VERB'), Count: 1
# Tag: ('گوشی', 'NOUN'), Count: 1
# Tag: ('بیسار', 'NOUN,EZ'), Count: 1
# Tag: ('فکر', 'NOUN'), Count: 1
# Tag: ('تبدیلش', 'NOUN'), Count: 1
# Tag: ('دارمش', 'NOUN'), Count: 1
# Tag: ('درس', 'NOUN'), Count: 1
# Tag: ('بند', 'NOUN,EZ'), Count: 1
# Tag: ('باتری', 'NOUN'), Count: 1
# Tag: ('خودش', 'PRON'), Count: 1
# Tag: ('دفعه', 'NOUN'), Count: 1
# Tag: ('عالیه', 'ADJ,EZ'), Count: 1
# Tag: ('مبتدی', 'NOUN'), Count: 1
# Tag: ('میتوان', 'VERB'), Count: 1
# Tag: ('تشکر', 'NOUN'), Count: 1
# Tag: ('مطلوبی', 'ADJ'), Count: 1
# Tag: ('سفرهای', 'NOUN,EZ'), Count: 1
# Tag: ('کتری', 'NOUN,EZ'), Count: 1
# Tag: ('لنزنیاز', 'NOUN'), Count: 1
# Tag: ('ک', 'NOUN'), Count: 2
# Tag: ('سریع', 'ADJ'), Count: 1
# Tag: ('سوخت', 'NOUN'), Count: 1
# Tag: ('محض', 'NOUN,EZ'), Count: 1
# Tag: ('خونه', 'NOUN,EZ'), Count: 1
# Tag: ('اسپیکر', 'NOUN'), Count: 1
# Tag: ('سلاممن', 'NOUN'), Count: 1
# Tag: ('برا', 'ADP'), Count: 1
# Tag: ('تولید', 'NOUN,EZ'), Count: 1
# Tag: ('سالی', 'NOUN'), Count: 1
# Tag: ('نسبت', 'NOUN,EZ'), Count: 1
# Tag: ('هیچ', 'DET'), Count: 2
# Tag: ('موهام', 'NOUN'), Count: 1
# Tag: ('جاروی', 'NOUN,EZ'), Count: 1
# Tag: ('10روزی', 'NOUN'), Count: 1
# Tag: ('خوبهسفیده', 'VERB'), Count: 1
# Tag: ('چشم', 'NOUN'), Count: 1
# Tag: ('4', 'NUM'), Count: 1
# Tag: ('کیبورد', 'NOUN'), Count: 1
# Tag: ('بعضی', 'PRON'), Count: 1
# Tag: ('دوستم', 'NOUN'), Count: 1
# Tag: ('محل', 'NOUN,EZ'), Count: 1
# Tag: ('نیست', 'VERB'), Count: 1
# Tag: ('دور', 'ADP,EZ'), Count: 1
# Tag: ('کارم', 'NOUN'), Count: 1
# Tag: ('ماوسهای', 'NOUN,EZ'), Count: 1
# Tag: ('G700', 'NOUN'), Count: 1
# Tag: ('جایگزین', 'ADJ,EZ'), Count: 1
# Tag: ('کردم', 'VERB'), Count: 2
# Tag: ('شیک', 'ADJ'), Count: 1
# Tag: ('4', 'NUM,EZ'), Count: 1
# Tag: ('مهمترین', 'ADJ'), Count: 1
# Tag: ('حرارتی', 'ADJ'), Count: 1
# Tag: ('پایان', 'NOUN'), Count: 1
# Tag: ('سنگییینه', 'NOUN'), Count: 1
# Tag: ('هست', 'VERB'), Count: 1
# Tag: ('معجزهآسا', 'ADV'), Count: 1
# Tag: ('دیگه', 'PRON'), Count: 1
# Tag: ('خوبیه', 'ADJ'), Count: 1
# Tag: ('یکیشون', 'PRON'), Count: 1
# Tag: ('دوستان', 'NOUN,EZ'), Count: 1
# Tag: ('کردنش', 'NOUN'), Count: 1
# Tag: ('کافیه', 'NOUN'), Count: 1
# Tag: ('15', 'NUM'), Count: 1
# Tag: ('ضبط', 'NOUN'), Count: 1
# Tag: ('کنید', 'VERB'), Count: 1
# Tag: ('اگر', 'SCONJ'), Count: 5
# Tag: ('پورت', 'NOUN,EZ'), Count: 1
# Tag: ('توی', 'ADP,EZ'), Count: 1
# Tag: ('افسوس', 'NOUN'), Count: 1
# Tag: ('بدنه', 'NOUN,EZ'), Count: 1
# Tag: ('ضعیف', 'ADJ'), Count: 1
# Tag: ('بعد', 'CCONJ'), Count: 1
# Tag: ('پاور', 'NOUN'), Count: 1
# Tag: ('دهی', 'NOUN'), Count: 1
# Tag: ('بازی', 'NOUN,EZ'), Count: 1
# Tag: ('تا', 'ADP'), Count: 1
# Tag: ('کیفیت', 'NOUN'), Count: 1
# Tag: ('چندماهی', 'ADJ'), Count: 1
# Tag: ('مدل', 'NOUN'), Count: 1

# %% [markdown]
# # **Nouns**

# %%
noun_counts = {}
for tag, count in tag_counts.items():
    if 'NOUN' in tag or 'NOUN,EZ' in tag:
      noun_counts[tag] = count

sorted_nouns = sorted(noun_counts.items(), key=lambda x: x[1], reverse=True)
pd.DataFrame(sorted_nouns[:10], columns=['tag', 'count'])
# Out:
#                   tag  count
# 0     (پیشنهاد, NOUN)      8
# 1         (های, NOUN)      4
# 2          (کل, NOUN)      4
# 3   (برنامه, NOUN,EZ)      3
# 4       (کل, NOUN,EZ)      3
# 5        (ساعت, NOUN)      3
# 6        (نظرم, NOUN)      3
# 7    (گزینه, NOUN,EZ)      3
# 8      (کفش, NOUN,EZ)      2
# 9  (پیشنهاد, NOUN,EZ)      2
